# %%
# --- .NET assembly references (case matters in pythonnet) ---------------------
# Make sure TC client bin is discoverable first (TC_BIN must point to the DLL folder)
# e.g. setx TC_BIN "C:\Siemens\Teamcenter\soa_client\bin"
import os, sys
TC_BIN = os.environ.get("TC_BIN")
if TC_BIN and TC_BIN not in sys.path:
    sys.path.append(TC_BIN)

print(sys.path)
# Out:
# ['C:\\Users\\hvanniekerk\\AppData\\Roaming\\uv\\python\\cpython-3.13.5-windows-x86_64-none\\python313.zip', 'C:\\Users\\hvanniekerk\\AppData\\Roaming\\uv\\python\\cpython-3.13.5-windows-x86_64-none\\DLLs', 'C:\\Users\\hvanniekerk\\AppData\\Roaming\\uv\\python\\cpython-3.13.5-windows-x86_64-none\\Lib', 'C:\\Users\\hvanniekerk\\AppData\\Roaming\\uv\\python\\cpython-3.13.5-windows-x86_64-none', 'c:\\Users\\hvanniekerk\\OneDrive - GVW Group, LLC\\Python\\.venv', '', 'c:\\Users\\hvanniekerk\\OneDrive - GVW Group, LLC\\Python\\.venv\\Lib\\site-packages', 'c:\\Users\\hvanniekerk\\OneDrive - GVW Group, LLC\\Python\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\hvanniekerk\\OneDrive - GVW Group, LLC\\Python\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\hvanniekerk\\OneDrive - GVW Group, LLC\\Python\\.venv\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\hvanniekerk\\TC']

# %%
from glob import glob
import pathlib
import os
import clr

files = glob(os.path.join(TC_BIN, "*.dll"))
for f in files:
    if (
        "FCCNetClientProxy.dll" not in f
        and "FCCNetClientProxy_32.dll" not in f
        and "TcMemNetBinding_32.dll" not in f
        and "TcServerNetBinding_32.dll" not in f
        and 'TcSoaFMS_32.dll' not in f
        and 'Teamcenter_SSO_32.dll' not in f
    ):
        print(f"Loading {f} ...")
        clr.AddReference(f)
# Out:
# Loading C:\Users\hvanniekerk\TC\Abr0SoaAdvancedBomRollupStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Abr0SoaStrongModelAdvancedBomRollup.dll ...
# Loading C:\Users\hvanniekerk\TC\Ac0SoaActiveCollaborationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Ac0SoaStrongModelActiveCollaboration.dll ...
# Loading C:\Users\hvanniekerk\TC\Acp0SoaStrongModelAwControlPlan.dll ...
# Loading C:\Users\hvanniekerk\TC\Ads0SoaAdsFoundationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Ads1SoaStrongModelAwAdsFoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\Aed0SoaStrongModelAutomationElectricDesign.dll ...
# Loading C:\Users\hvanniekerk\TC\Aft0SoaStrongModelSafetyarchitectint.dll ...
# Loading C:\Users\hvanniekerk\TC\Am0SoaStrongModelAccessManagerAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Amx0SoaAssignmentMatrixStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Amx0SoaStrongModelAssignmentMatrix.dll ...
# Loading C:\Users\hvanniekerk\TC\Amx1SoaStrongModelAssignmentmatrixaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Ap0SoaStrongModelAdvancePlanner.dll ...
# Loading C:\Users\hvanniekerk\TC\Apb0SoaStrongModelAttrParmBase.dll ...
# Loading C:\Users\hvanniekerk\TC\Apm0SoaStrongModelApqpProgramMgt.dll ...
# Loading C:\Users\hvanniekerk\TC\Aps0SoaStrongModelApsCore.dll ...
# Loading C:\Users\hvanniekerk\TC\Aqc0SoaStrongModelQcmaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Arm0SoaStrongModelActiveWorkspaceReqMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Arm0SoaStrongModelAwReqMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Arm1SoaAwReqMgmtSeStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Arm1SoaStrongModelAwReqMgmtSe.dll ...
# Loading C:\Users\hvanniekerk\TC\As0SoaAspCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\As0SoaStrongModelAutoSupplier.dll ...
# Loading C:\Users\hvanniekerk\TC\As1SoaStrongModelAutoSupplierAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Ase0SoaActiveWorkspaceSysEngStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Ase0SoaStrongModelActiveWorkspaceSysEng.dll ...
# Loading C:\Users\hvanniekerk\TC\Ase1SoaStrongModelSystemsModeling.dll ...
# Loading C:\Users\hvanniekerk\TC\Asp0SoaAspectStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Asp0SoaStrongModelAspect.dll ...
# Loading C:\Users\hvanniekerk\TC\Att0SoaAttrTargetMgmtStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Att0SoaStrongModelAttrTargetMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Att1SoaAttrTargetMgmtAWStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Att1SoaStrongModelAttrTargetMgmtAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Aut0SoaStrongModelAuthorizationAws.dll ...
# Loading C:\Users\hvanniekerk\TC\Awa0SoaStrongModelAwAssistant.dll ...
# Loading C:\Users\hvanniekerk\TC\Awb0SoaActiveWorkspaceBomStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awb0SoaEntCbaStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awb0SoaStrongModelActiveWorkspaceBom.dll ...
# Loading C:\Users\hvanniekerk\TC\Awb0SoaStructureStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awb0SoaXlsBomStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awn0SoaNXStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awp0SoaAWS2Strong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awp0SoaMarkupStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awp0SoaStrongModelAWS2.dll ...
# Loading C:\Users\hvanniekerk\TC\Awv0SoaActiveWorkspaceVisStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Awv0SoaStrongModelActiveWorkspaceVis.dll ...
# Loading C:\Users\hvanniekerk\TC\Bdo0SoaStrongModelBranchDataOrganization.dll ...
# Loading C:\Users\hvanniekerk\TC\Bhv0SoaBranchFoundationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Bhv0SoaStrongModelBranchfoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\Bhv1SoaBranchingAndVersioningStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Bhv1SoaStrongModelBranchingAndVersioning.dll ...
# Loading C:\Users\hvanniekerk\TC\Bom0SoaBomCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Bom0SoaStrongModelBomManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Cab0SoaStrongModelCable.dll ...
# Loading C:\Users\hvanniekerk\TC\Cad0SoaStrongModelCadlite.dll ...
# Loading C:\Users\hvanniekerk\TC\CAE0SoaSimProcStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\CAE0SoaStrongModelSimProc.dll ...
# Loading C:\Users\hvanniekerk\TC\Cae1SoaCaeAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cae1SoaStrongModelCaeAw.dll ...
# Loading C:\Users\hvanniekerk\TC\CAW0SoaStrongModelCapaonawc.dll ...
# Loading C:\Users\hvanniekerk\TC\Cba1SoaCbaExtStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cbm0SoaColorBomPmmStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cbm0SoaStrongModelColorBomPmm.dll ...
# Loading C:\Users\hvanniekerk\TC\Cdm0SoaContractManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cdm1SoaStrongModelAwContractManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Cfg0SoaConfiguratorStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cfg0SoaStrongModelConfigurator.dll ...
# Loading C:\Users\hvanniekerk\TC\Cfg1SoaStrongModelConfigurator.dll ...
# Loading C:\Users\hvanniekerk\TC\Cfp0SoaStrongModelFeaturePlanning.dll ...
# Loading C:\Users\hvanniekerk\TC\Cif0SoaIntegrationFrameworkStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cif0SoaStrongModelIntegrationFramework.dll ...
# Loading C:\Users\hvanniekerk\TC\Cip0SoaStrongModelControlInSPPlan.dll ...
# Loading C:\Users\hvanniekerk\TC\Civ0SoaContMgmtS1000D40Strong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cla0SoaClassificationCommonStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Clr0SoaColorAppearanceStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Clr0SoaStrongModelColorAppearance.dll ...
# Loading C:\Users\hvanniekerk\TC\Clr1SoaStrongModelColorRule.dll ...
# Loading C:\Users\hvanniekerk\TC\Cls0SoaClassificationCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cm1SoaCmAwsStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cm1SoaStrongModelCmaws.dll ...
# Loading C:\Users\hvanniekerk\TC\Cp0SoaStrongModelComposites.dll ...
# Loading C:\Users\hvanniekerk\TC\CPA0SoaStrongModelCapaDataModel.dll ...
# Loading C:\Users\hvanniekerk\TC\Cpd0SoaCpdCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Crf0SoaStrongModelCprFoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\Crt0SoaStrongModelValidationContract.dll ...
# Loading C:\Users\hvanniekerk\TC\Crt0SoaValidationContractStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Crt1SoaStrongModelValidationContractAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Crt1SoaValidationContractAWStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Cs0SoaStrongModelComponentSupplierAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Ct0SoaStrongModelCost.dll ...
# Loading C:\Users\hvanniekerk\TC\Ct1SoaStrongModelCost.dll ...
# Loading C:\Users\hvanniekerk\TC\Ctm1SoaStrongModelContMgmtAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Dds0SoaDataDiscoveryStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Dds0SoaStrongModelDataDiscovery.dll ...
# Loading C:\Users\hvanniekerk\TC\Dia0SoaDiagrammingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Dma1SoaDocMgmtAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Dma1SoaStrongModelDocMgmtAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Dpv1SoaStrongModelDpvAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Ebm0SoaStrongModelEnterpriseBOM.dll ...
# Loading C:\Users\hvanniekerk\TC\Ebm1SoaStrongModelAwEBom.dll ...
# Loading C:\Users\hvanniekerk\TC\Ebm6SoaStrongModelTesteBOMPerf.dll ...
# Loading C:\Users\hvanniekerk\TC\Ebm9SoaStrongModelCustomebom.dll ...
# Loading C:\Users\hvanniekerk\TC\Ec0SoaStrongModelEngChange.dll ...
# Loading C:\Users\hvanniekerk\TC\Eda0SoaEDMDCollabStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Eda1SoaStrongModelEdaserveraw.dll ...
# Loading C:\Users\hvanniekerk\TC\Eml0SoaStrongModelEntArchModeling.dll ...
# Loading C:\Users\hvanniekerk\TC\Epc0SoaStrongModelMfgbvrmaturity.dll ...
# Loading C:\Users\hvanniekerk\TC\Ept0SoaStrongModelTimeAnalysis.dll ...
# Loading C:\Users\hvanniekerk\TC\Ept3SoaStrongModelTest.dll ...
# Loading C:\Users\hvanniekerk\TC\Esm0SoaESMBaseStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Esw0SoaStrongModelEsmgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Evm1SoaStrongModelViewMgmtAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Evm1SoaViewMgmtAWStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Ewi0SoaEwiaStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Ewi0SoaStrongModelEwia.dll ...
# Loading C:\Users\hvanniekerk\TC\Fdp0SoaFourDPlanningStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fdp0SoaStrongModelFourDPlanning.dll ...
# Loading C:\Users\hvanniekerk\TC\Fgb0SoaStrongModelAw4GBom.dll ...
# Loading C:\Users\hvanniekerk\TC\Fgd0SoaStrongModelAw4GDesign.dll ...
# Loading C:\Users\hvanniekerk\TC\Fgf0SoaStrongModelAw4GFoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\Fha0SoaStrongModelFHAnalysis.dll ...
# Loading C:\Users\hvanniekerk\TC\FMSNetTicket.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaAuditManagerStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaConfigFilterCriteriaStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaDiagrammingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaEditContextStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaNotificationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaParticipantStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaQualificationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaUiConfigStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaUmsStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fnd0SoaWProxyStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fs0SoaFunctionalSafetyStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Fs0SoaStrongModelFunctionalsafety.dll ...
# Loading C:\Users\hvanniekerk\TC\FSCNetClientProxy.dll ...
# Loading C:\Users\hvanniekerk\TC\Gtp0SoaStrongModelGtpowerint.dll ...
# Loading C:\Users\hvanniekerk\TC\IAE1SoaStrongModelVerificationManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\IAE1SoaVerificationManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\IAV0SoaStrongModelVerificationManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\IAV1SoaStrongModelVerificationManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Icc0SoaStrongModelAwInContextChange.dll ...
# Loading C:\Users\hvanniekerk\TC\Icd0SoaStrongModelIppeCdmExt.dll ...
# Loading C:\Users\hvanniekerk\TC\Icp0SoaStrongModelCampaignMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\ICSharpCode.SharpZipLib.dll ...
# Loading C:\Users\hvanniekerk\TC\Iim0SoaStrongModelIdeaMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Il0SoaStrongModelImaginelab.dll ...
# Loading C:\Users\hvanniekerk\TC\Im0SoaStrongModelIndustryMachinery.dll ...
# Loading C:\Users\hvanniekerk\TC\Im1SoaStrongModelIndustryMachineryAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Imd0SoaMedicalDeviceStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Imd0SoaStrongModelMedicalDevice.dll ...
# Loading C:\Users\hvanniekerk\TC\Imp0SoaLabelManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Imp0SoaStrongModelLabelManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Ipc0SoaStrongModelCpgIpmCatalyst.dll ...
# Loading C:\Users\hvanniekerk\TC\Ipm0SoaStrongModelIntegProgMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Ipp0SoaStrongModelIppeCore.dll ...
# Loading C:\Users\hvanniekerk\TC\Ipt0SoaStrongModelTC4IPMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Isi0SoaStrongModelIPManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Lbr0SoaLibraryManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Lcm1SoaStrongModelLdfcmAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Ldf0SoaStrongModelLdfAws.dll ...
# Loading C:\Users\hvanniekerk\TC\Les0SoaStrongModelLisesm.dll ...
# Loading C:\Users\hvanniekerk\TC\Lgt0SoaLogisticsStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Lgt0SoaStrongModelLogistics.dll ...
# Loading C:\Users\hvanniekerk\TC\Lis0SoaLdfStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Lis0SoaStrongModelLdf.dll ...
# Loading C:\Users\hvanniekerk\TC\Lpa0SoaStrongModelLdfPolAws.dll ...
# Loading C:\Users\hvanniekerk\TC\Lrm0SoaStrongModelLisrm.dll ...
# Loading C:\Users\hvanniekerk\TC\Lrm1SoaStrongModelLdfrmAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Mac0SoaManufacturingCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mac0SoaStrongModelMfgApsCore.dll ...
# Loading C:\Users\hvanniekerk\TC\Mad0SoaStrongModelMadeint.dll ...
# Loading C:\Users\hvanniekerk\TC\Mat1SoaMaterialMgmtStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mbc0SoaMfgBvrCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mbc0SoaStrongModelMfgBvrCore.dll ...
# Loading C:\Users\hvanniekerk\TC\Mbm0SoaMultiBomManagerStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mbm0SoaStrongModelMultibommanagerweb.dll ...
# Loading C:\Users\hvanniekerk\TC\Mci0SoaPMIManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mci0SoaStrongModelPMIManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdc0SoaMDConnectivityStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdl0SoaModelCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdo0SoaMDOManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdo0SoaStrongModelMdo.dll ...
# Loading C:\Users\hvanniekerk\TC\Mds0SoaStrongModelMedDevFoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdt0SoaMDRTransmittalsStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdt0SoaStrongModelMDRTransmittals.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdt1SoaStrongModelMdrtransmittalsaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Mdw0SoaStrongModelMagicdraw.dll ...
# Loading C:\Users\hvanniekerk\TC\Mea0SoaStrongModelMea0Fpam.dll ...
# Loading C:\Users\hvanniekerk\TC\Mei0SoaMESIntegStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mei0SoaStrongModelMESInteg.dll ...
# Loading C:\Users\hvanniekerk\TC\Mii0SoaStrongModelMdrtippeinterface.dll ...
# Loading C:\Users\hvanniekerk\TC\Mmg0SoaStrongModelFormulationMaterialMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Mpc0SoaManufacturingCMStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mpc0SoaStrongModelMprCm.dll ...
# Loading C:\Users\hvanniekerk\TC\Mpr0SoaProcessStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Mpr0SoaStrongModelCmtProcess.dll ...
# Loading C:\Users\hvanniekerk\TC\Mq0SoaStrongModelHara.dll ...
# Loading C:\Users\hvanniekerk\TC\Mrm0SoaStrongModelMfgResourceMgrAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Mtw0SoaStrongModelMaterialMgmtAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Newtonsoft.Json.dll ...
# Loading C:\Users\hvanniekerk\TC\Nxc0SoaTcinCpdStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Nxl0SoaStrongModelLogical.dll ...
# Loading C:\Users\hvanniekerk\TC\Nxp1SoaStrongModelPidAws.dll ...
# Loading C:\Users\hvanniekerk\TC\Nxs0SoaStrongModelAwNxSdpd.dll ...
# Loading C:\Users\hvanniekerk\TC\Obs0SoaStrongModelOrgBreakdown.dll ...
# Loading C:\Users\hvanniekerk\TC\Obs1SoaStrongModelAwOrgBreakdown.dll ...
# Loading C:\Users\hvanniekerk\TC\Ods0SoaObjectDataServicesStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Ods0SoaStrongModelObjectDataServices.dll ...
# Loading C:\Users\hvanniekerk\TC\Ods9SoaStrongModelObjectDataServicesTest.dll ...
# Loading C:\Users\hvanniekerk\TC\Ord0SoaStrongModelOrderManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Osl0SoaStrongModelLISOSLC.dll ...
# Loading C:\Users\hvanniekerk\TC\Pca0SoaStrongModelAwConfigurator.dll ...
# Loading C:\Users\hvanniekerk\TC\Pch0SoaStrongModelPchInterface.dll ...
# Loading C:\Users\hvanniekerk\TC\Pdg0SoaStrongModelPtnDesignGdlines.dll ...
# Loading C:\Users\hvanniekerk\TC\Pdm0SoaPlantDataMgmtStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Pdm0SoaStrongModelPlantDataMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Pdm1SoaStrongModelPlantDataMgmtAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Pec0SoaStrongModelPpEventChange.dll ...
# Loading C:\Users\hvanniekerk\TC\Pfp0SoaFeaturePlanningStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Pgp0SoaPrgPlanningAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Pgp0SoaStrongModelAwPrgPlanning.dll ...
# Loading C:\Users\hvanniekerk\TC\Pm0SoaStrongModelPartManufacturing.dll ...
# Loading C:\Users\hvanniekerk\TC\Pm1SoaStrongModelPartmanufacturingaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Pma0SoaStrongModelAutomation.dll ...
# Loading C:\Users\hvanniekerk\TC\Pma1SoaBOMAutomationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Pma1SoaStrongModelAwautomation.dll ...
# Loading C:\Users\hvanniekerk\TC\Pmg0SoaStrongModelCpMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Ppe0SoaStrongModelElectronicsPlanner.dll ...
# Loading C:\Users\hvanniekerk\TC\Prf1SoaStrongModelPrefMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Prg0SoaProgramInfraStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Prg0SoaStrongModelProgramInfra.dll ...
# Loading C:\Users\hvanniekerk\TC\Prg1SoaProgramPlanningAppStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Prg1SoaStrongModelProgramPlanningApp.dll ...
# Loading C:\Users\hvanniekerk\TC\Psi0SoaPPSMInterfaceAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Psi0SoaStrongModelPpsmInterface.dll ...
# Loading C:\Users\hvanniekerk\TC\Psm0SoaStrongModelProductSpecMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Ptn0SoaPartitionStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Qa0SoaStrongModelQualityAudit.dll ...
# Loading C:\Users\hvanniekerk\TC\Qam0SoaStrongModelQualityActionMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Qc0SoaStrongModelQualityCenterBase.dll ...
# Loading C:\Users\hvanniekerk\TC\Qfm0SoaStrongModelQcfmea.dll ...
# Loading C:\Users\hvanniekerk\TC\Ram0SoaStrongModelRamsmodeling.dll ...
# Loading C:\Users\hvanniekerk\TC\Ram1SoaStrongModelRamsmodelingaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Rb0SoaStrongModelReportingaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Rem0SoaStrongModelReminderAndEscalationMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\Ret1SoaStrongModelRetailAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Rhp0SoaStrongModelRhapsody.dll ...
# Loading C:\Users\hvanniekerk\TC\Rlz0SoaRealizationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Roc0SoaStrongModelRulesOfCredit.dll ...
# Loading C:\Users\hvanniekerk\TC\Rse0SoaStrongModelTcRsEnablement.dll ...
# Loading C:\Users\hvanniekerk\TC\Rv1SoaRelationshipViewerStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Rv1SoaStrongModelRelationshipViewer.dll ...
# Loading C:\Users\hvanniekerk\TC\S2clSoaSocialStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\S2clSoaStrongModelSocial.dll ...
# Loading C:\Users\hvanniekerk\TC\Sab1SoaStrongModelAsBuiltAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Sam1SoaStrongModelAsMaintainedAw.dll ...
# Loading C:\Users\hvanniekerk\TC\SAS0SoaSvcAutoSchedulingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Saw1SoaProjectManagementAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sc0SoaStrongModelSuppliercollaboration.dll ...
# Loading C:\Users\hvanniekerk\TC\Sc0SoaSupplierCollaborationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sc1SoaStrongModelSupplierCollaborationAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Scd0SoaStrongModelScip.dll ...
# Loading C:\Users\hvanniekerk\TC\Sci0SoaIMDSIntegrationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sci1SoaIMDSIntegrationAWStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sci1SoaStrongModelImdsIntegrationAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Scp0SoaSubsCmplStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Scw0SoaStrongModelSubsCmplAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Sdm0SoaStrongModelSampleDocMgt.dll ...
# Loading C:\Users\hvanniekerk\TC\Sen1SoaServiceEngineeringAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Settings.AppSettings.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Sinks.Console.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Sinks.Email.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Sinks.EventLog.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Sinks.File.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Sinks.PeriodicBatching.dll ...
# Loading C:\Users\hvanniekerk\TC\Serilog.Sinks.RollingFile.dll ...
# Loading C:\Users\hvanniekerk\TC\Sfd0SoaSemiconductorFoundationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sfd0SoaStrongModelSemiconductorFoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\Sis0SoaSocialIntStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Smc0SoaBuildCombinationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Smc0SoaStrongModelPsMcfgSupport.dll ...
# Loading C:\Users\hvanniekerk\TC\Smc0SoaStructureManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Smr1SoaMrocoreAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Smr1SoaStrongModelMrocoreAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Spl0SoaStrongModelServiceplanning.dll ...
# Loading C:\Users\hvanniekerk\TC\Srh0SoaStrongModelApsConfiguredSearch.dll ...
# Loading C:\Users\hvanniekerk\TC\SS1SoaStrongModelShapeSearch.dll ...
# Loading C:\Users\hvanniekerk\TC\SSF0SoaServiceForecastingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\SSF0SoaStrongModelServiceForecasting.dll ...
# Loading C:\Users\hvanniekerk\TC\Ssf1SoaStrongModelServiceForecastingAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Ssm0SoaStrongModelSystemSynthesisModeling.dll ...
# Loading C:\Users\hvanniekerk\TC\SSP0SoaStrongModelServicePlanning.dll ...
# Loading C:\Users\hvanniekerk\TC\SSS0SoaStrongModelServiceScheduling.dll ...
# Loading C:\Users\hvanniekerk\TC\SSS0SoaSvcSchedulingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sub0SoaNotificationAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sub0SoaStrongModelSubscription.dll ...
# Loading C:\Users\hvanniekerk\TC\Swi1SoaStrongModelSlmServiceWiAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Swi1SoaSvcWorkInstructionsAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Sys1SoaStrongModelSystemmodelingintaw.dll ...
# Loading C:\Users\hvanniekerk\TC\System.Configuration.ConfigurationManager.dll ...
# Loading C:\Users\hvanniekerk\TC\Tca0SoaTcmAccessStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcLogging.dll ...
# Loading C:\Users\hvanniekerk\TC\TcMemNetBinding.dll ...
# Loading C:\Users\hvanniekerk\TC\TcMemNetBindingInterface.dll ...
# Loading C:\Users\hvanniekerk\TC\TcServerNetBinding.dll ...
# Loading C:\Users\hvanniekerk\TC\TcServerNetBindingInterface.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAdministrationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAiStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAllocationsStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAsbAsmAlignmentStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAsBuiltStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAsMaintainedStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaAuthorizedDataAccessStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaBehaviorModelingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaBomStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaBusinessModelerStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCadBomAlignmentStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCadStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCaeStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCalendarManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaChangeManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaClassificationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaClient.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCommon.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCommon.XmlSerializers.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaContMgmtBaseStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaDocumentManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaFMS.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaFSC.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaGlobalMultiSiteStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaImportExportStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaIssueManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaManufacturingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaMESStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaMROCoreStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaMultisiteStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaParameterManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaProductionManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaProjectManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaQueryStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaRdvStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaReportsStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaRequirementsManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaSrmIntegrationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModel.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelAdsChangeManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelAdsFoundation.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelAis1AiMlService.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelAsBuilt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelAsMaintained.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelBehaviorModeling.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelBrndMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCba.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCcdm.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCdm0ContractManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelClassificationCore.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCm.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCmtEbop.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCmtEmserver.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCmtPadTwp.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelContmgmtBase.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelContmgmtDita.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelContmgmtS1000d.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelContmgmtS1000d40.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCpdCore.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelCpgMaterials.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelDiagramming.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelDpv.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEdaLibrary.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEdaServer.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEmps.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEsddm.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEsmBase.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEsmProcessor.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelEsmSoftware.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelFnshmgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelFpMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelGmo.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelHrn.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelIssuemgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelLibraryManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelMaterialMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelMatlabint.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelMDConnectivity.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelMES.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelMesIssueMgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelModelCore.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelMROCore.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelNX0tcin.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelNXB0stage.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelNXP0pid.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelPartition.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelPenetrationmgmt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelPkgArt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelPlp0ProdLinePlan.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelPMI.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelProductVariant.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelRealization.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelRetail.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelScdt.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSci0IMDSIntegration.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelScmCc.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelServiceEventManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelServiceProcessing.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelServiceRequest.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSmdsysmodeling.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSpecMgr.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSSPSPRAlignment.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelStockMaterial.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSubsCmpl.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSym0systemmodelingint.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelSystemsEngineering.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelTcae.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelTransactionProcessing.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelVendorManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelWeldManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStrongModelWorkPackageManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaStructureManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaSvcProcessingStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaSvcRequestStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaSystemsEngineeringStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaTranslationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaVendorManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaVisualizationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaWireHarnessStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\TcSoaWorkflowStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Teamcenter_SSO.dll ...
# Loading C:\Users\hvanniekerk\TC\Teamcenter_SSOloader.dll ...
# Loading C:\Users\hvanniekerk\TC\Tgm0SoaStrongModelTargetManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Tgm0SoaTargetManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Tie0SoaStrongModelAW.dll ...
# Loading C:\Users\hvanniekerk\TC\Tm0SoaStrongModelTestManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Tm0SoaTestManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Tq0SoaStrongModelTrainingQualification.dll ...
# Loading C:\Users\hvanniekerk\TC\Txl0SoaTcxLiteStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Txn0SoaStrongModelMonitor.dll ...
# Loading C:\Users\hvanniekerk\TC\Um0SoaStrongModelUserManagement.dll ...
# Loading C:\Users\hvanniekerk\TC\Uml0SoaStrongModelUmlSysml.dll ...
# Loading C:\Users\hvanniekerk\TC\Uml0SoaUmlSysmlStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Uml1SoaStrongModelUmlsysmlaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Usp0SoaStrongModelSupPortal.dll ...
# Loading C:\Users\hvanniekerk\TC\Usp0SoaSupportalStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Usp1SoaStrongModelSupPortalAw.dll ...
# Loading C:\Users\hvanniekerk\TC\Val0SoaNXValidationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Val0SoaStrongModelNXValidation.dll ...
# Loading C:\Users\hvanniekerk\TC\Val1SoaCfgValidationStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Val1SoaStrongModelCfgValidation.dll ...
# Loading C:\Users\hvanniekerk\TC\Vm1SoaStrongModelVendormanagementaw.dll ...
# Loading C:\Users\hvanniekerk\TC\Vm1SoaVendorManagementAWStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Wbs0SoaStrongModelWorkBreakDownStructure.dll ...
# Loading C:\Users\hvanniekerk\TC\WdM0SoaWeldManagementStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Wnb0SoaStrongModelWeightandBalance.dll ...
# Loading C:\Users\hvanniekerk\TC\Wnb0SoaWeightAndBalanceStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Wnb1SoaWeightandBalanceAwStrong.dll ...
# Loading C:\Users\hvanniekerk\TC\Xc0SoaStrongModelShareCollaboration.dll ...
# Loading C:\Users\hvanniekerk\TC\Xst0SoaStrongModelXSearch.dll ...

# %%
# dm_resolver.py
from __future__ import annotations

import importlib
from typing import Any, Tuple, Optional, Iterable

# pythonnet / .NET
import System
from System import AppDomain


def _iter_types() -> Iterable[System.Type]:
    for asm in AppDomain.CurrentDomain.GetAssemblies():
        try:
            for t in asm.GetTypes():
                yield t
        except Exception:
            # Some reflection-only or dynamic assemblies may throw
            continue


def _pick_service_type() -> Optional[System.Type]:
    """Prefer Strong.* DataManagementService; else Core.*."""
    strong: list[System.Type] = []
    weak:   list[System.Type] = []
    for t in _iter_types():
        try:
            if t is None or t.Namespace is None:
                continue
            if t.Name != "DataManagementService":
                continue
            full = t.FullName or ""
            if ".Services.Strong." in full:
                strong.append(t)
            elif ".Services.Core" in full:
                weak.append(t)
        except Exception:
            continue

    # Heuristic: prefer Strong.*; if multiple, prefer ones in Cad/Core domains, in that order.
    def _score(tt: System.Type) -> tuple[int, int]:
        f = tt.FullName or ""
        # domain preference: Cad first (common for DM strong in some kits), then Core, otherwise neutral
        dom_score = 0
        if ".Strong.Cad." in f:
            dom_score = 2
        elif ".Strong.Core." in f:
            dom_score = 1
        return (1, dom_score) if ".Services.Strong." in f else (0, 0)

    if strong:
        strong.sort(key=_score, reverse=True)
        return strong[0]
    if weak:
        return weak[0]
    return None


def _candidate_dm_type_namespaces(base_ns: str) -> list[str]:
    """
    Build a candidate list like:
      base_ns + (._YYYY_MM)? + .Datamanagement or .DataManagement
    Then extend by *observed* namespaces in loaded assemblies that match base_ns.
    """
    # Usual suspects first
    common_versions = ["_2015_10","_2012_09","_2011_06","_2010_09","_2008_06","_2007_06","_2006_03",""]
    suffixes = ["Datamanagement", "DataManagement"]

    initial = []
    for ver in common_versions:
        for suf in suffixes:
            if ver:
                initial.append(f"{base_ns}.{ver}.{suf}")
            else:
                initial.append(f"{base_ns}.{suf}")

    # Now derive from *actual loaded* types
    observed = set()
    for t in _iter_types():
        ns = t.Namespace
        if not ns or not ns.startswith(base_ns + "."):
            continue
        last = ns.split(".")[-1]
        if last in ("Datamanagement", "DataManagement"):
            observed.add(ns)

    # Merge with initial, preserving order (observed first — reality beats guesses)
    ordered = list(observed) + [ns for ns in initial if ns not in observed]
    return ordered


def _import_ns(ns: str) -> Optional[Any]:
    try:
        return importlib.import_module(ns)
    except Exception:
        return None


def resolve_dm_namespace(verbose: bool = False) -> Tuple[Any, Any, str, str]:
    """
    Returns:
        (DMServiceClass, DMTypesModule, flavor, types_namespace_str)

        - DMServiceClass: the .NET class exposing static GetService(Connection)
        - DMTypesModule:  the Python module wrapper for the Datamanagement/DataManagement namespace
        - flavor:         'strong' or 'weak'
        - types_namespace_str: the fully-qualified namespace string for types
    Raises:
        ImportError if nothing suitable is found.
    """
    svc_type = _pick_service_type()
    if not svc_type:
        raise ImportError(
            "No DataManagementService type found in loaded assemblies. "
            "Check that TcSoa* and TcServices* DLLs are actually loaded."
        )

    base_ns = svc_type.Namespace  # e.g., Teamcenter.Services.Strong.Cad  or Teamcenter.Services.Core
    flavor = "strong" if ".Services.Strong." in base_ns else "weak"

    if verbose:
        print(f"[dm] service: {svc_type.FullName}  (base_ns={base_ns}, flavor={flavor})")

    # 1) Try to locate types under the same domain (base_ns)
    tried: list[str] = []
    for cand in _candidate_dm_type_namespaces(base_ns):
        tried.append(cand)
        mod = _import_ns(cand)
        if mod is not None:
            if verbose:
                print(f"[dm] types: {cand}")
            return svc_type, mod, flavor, cand

    # 2) If that failed (e.g., service lives in Strong.Cad but types landed in Strong.Core),
    #    scan all loaded namespaces for *any* Strong.* Datamanagement/DataManagement.
    global_candidates = set()
    for t in _iter_types():
        ns = t.Namespace
        if not ns:
            continue
        if ".Services.Strong." in ns:
            last = ns.split(".")[-1]
            if last in ("Datamanagement", "DataManagement"):
                global_candidates.add(ns)

    for cand in sorted(global_candidates):
        tried.append(cand)
        mod = _import_ns(cand)
        if mod is not None:
            if verbose:
                print(f"[dm] types (cross-domain): {cand}")
            return svc_type, mod, "strong", cand

    # 3) Fall back to weak-typed Core if available
    try:
        import Teamcenter.Services.Core as Core
        mod = _import_ns("Teamcenter.Services.Core._2006_03.DataManagement")
        if mod is not None:
            if verbose:
                print("[dm] falling back to weak-typed Core._2006_03.DataManagement")
            return Core.DataManagementService, mod, "weak", "Teamcenter.Services.Core._2006_03.DataManagement"
    except Exception:
        pass

    msg = [
        f"Found service type {svc_type.FullName}, but could not resolve its Datamanagement/DataManagement types.",
        "Namespaces tried (in order):",
        *("  - " + s for s in tried),
        "Make sure your TC client kit with strong proxies is fully loaded and note that some kits place",
        "DataManagement types under different domains (e.g., Strong.Cad vs Strong.Core) or different version folders."
    ]
    raise ImportError("\n".join(msg))


def get_service_factory(DMServiceClass: Any):
    """Return a small factory that does DMServiceClass.GetService(conn)."""
    def _factory(conn: Any) -> Any:
        return DMServiceClass.GetService(conn)
    return _factory


def list_available_dm_namespaces() -> list[str]:
    """Utility to help you see what the kit exposes."""
    ns = set()
    for t in _iter_types():
        n = t.Namespace
        if not n:
            continue
        tail = n.split(".")[-1]
        if tail in ("Datamanagement", "DataManagement"):
            ns.add(n)
    return sorted(ns)

# %%
for t in _iter_types():
    ns = t.Namespace
    if ns is not None and ns.startswith("Teamcenter"):
        print(t.FullName)
# Out:
# Teamcenter.Soa.SoaConstants
# Teamcenter.Soa.Internal.Common.AnyCredentials
# Teamcenter.Soa.Internal.Common.NoDTDResolver
# Teamcenter.Soa.Internal.Common.AuthUtils
# Teamcenter.Soa.Internal.Common.Monitor
# Teamcenter.Soa.Internal.Common.PolicyMarshaller
# Teamcenter.Soa.Exceptions.CanceledOperationException
# Teamcenter.Soa.Exceptions.ExceptionMapper
# Teamcenter.Soa.Exceptions.NotLoadedException
# Teamcenter.Soa.Common.ObjectPropertyPolicy
# Teamcenter.Soa.Common.PolicyProperty
# Teamcenter.Soa.Common.PolicyType
# Teamcenter.Soa.Common.Tpc
# Teamcenter.Soa.Common.TpcPackage
# Teamcenter.Soa.Common.Version
# Teamcenter.Soa.Common.Utils.XmlBindingUtils
# Teamcenter.Schemas.Soa.Objectpropertypolicy.ObjectPropertyPolicy
# Teamcenter.Schemas.Soa.Objectpropertypolicy.ObjectType
# Teamcenter.Schemas.Soa.Objectpropertypolicy.Property
# Teamcenter.Schemas.Soa._2006_09.Clientcontext.NameBooleanValue
# Teamcenter.Schemas.Soa._2006_09.Clientcontext.NameIntegerValue
# Teamcenter.Schemas.Soa._2006_09.Clientcontext.NameStringValue
# Teamcenter.Schemas.Soa._2006_09.Clientcontext.RequestBody
# Teamcenter.Schemas.Soa._2006_09.Clientcontext.RequestEnvelope
# Teamcenter.Schemas.Soa._2006_09.Clientcontext.RequestHeader
# Teamcenter.Schemas.Soa._2011_06.Metamodel.ActionReference
# Teamcenter.Schemas.Soa._2011_06.Metamodel.AttachedLov
# Teamcenter.Schemas.Soa._2011_06.Metamodel.BasedOn
# Teamcenter.Schemas.Soa._2011_06.Metamodel.Bounds
# Teamcenter.Schemas.Soa._2011_06.Metamodel.Constant
# Teamcenter.Schemas.Soa._2011_06.Metamodel.DatasetAction
# Teamcenter.Schemas.Soa._2011_06.Metamodel.DatasetReferenceInfo
# Teamcenter.Schemas.Soa._2011_06.Metamodel.DatasetReference
# Teamcenter.Schemas.Soa._2011_06.Metamodel.DatasetType
# Teamcenter.Schemas.Soa._2011_06.Metamodel.Index
# Teamcenter.Schemas.Soa._2011_06.Metamodel.KeyValue
# Teamcenter.Schemas.Soa._2011_06.Metamodel.L10NData
# Teamcenter.Schemas.Soa._2011_06.Metamodel.LovData
# Teamcenter.Schemas.Soa._2011_06.Metamodel.LovInfo
# Teamcenter.Schemas.Soa._2011_06.Metamodel.LovL10N
# Teamcenter.Schemas.Soa._2011_06.Metamodel.LovReference
# Teamcenter.Schemas.Soa._2011_06.Metamodel.LovValueL10N
# Teamcenter.Schemas.Soa._2011_06.Metamodel.LovValue
# Teamcenter.Schemas.Soa._2011_06.Metamodel.ModelSchema
# Teamcenter.Schemas.Soa._2011_06.Metamodel.ModelType
# Teamcenter.Schemas.Soa._2011_06.Metamodel.NamingRule
# Teamcenter.Schemas.Soa._2011_06.Metamodel.PropertyDescriptor
# Teamcenter.Schemas.Soa._2011_06.Metamodel.PropertyL10N
# Teamcenter.Schemas.Soa._2011_06.Metamodel.Renderer
# Teamcenter.Schemas.Soa._2011_06.Metamodel.RevNameRule
# Teamcenter.Schemas.Soa._2011_06.Metamodel.RulePattern
# Teamcenter.Schemas.Soa._2011_06.Metamodel.ToolData
# Teamcenter.Schemas.Soa._2011_06.Metamodel.Tool
# Teamcenter.Schemas.Soa._2011_06.Metamodel.TypeL10N
# Teamcenter.Schemas.Soa._2011_06.Metamodel.TypeSchema
# Teamcenter.Schemas.Soa._2006_03.Base.Attrib
# Teamcenter.Schemas.Soa._2006_03.Base.CompoundProperty
# Teamcenter.Schemas.Soa._2006_03.Base.CreateInput
# Teamcenter.Schemas.Soa._2006_03.Base.DisplayProperty
# Teamcenter.Schemas.Soa._2006_03.Base.ErrorStack
# Teamcenter.Schemas.Soa._2006_03.Base.ErrorValue
# Teamcenter.Schemas.Soa._2006_03.Base.ModelClass
# Teamcenter.Schemas.Soa._2006_03.Base.ModelObject
# Teamcenter.Schemas.Soa._2006_03.Base.ModelSchema
# Teamcenter.Schemas.Soa._2006_03.Base.ModelType
# Teamcenter.Schemas.Soa._2006_03.Base.Modifiers
# Teamcenter.Schemas.Soa._2006_03.Base.ObjectMap
# Teamcenter.Schemas.Soa._2006_03.Base.ObjectPropertyPolicy
# Teamcenter.Schemas.Soa._2006_03.Base.PartialErrors
# Teamcenter.Schemas.Soa._2006_03.Base.PolicyProperty
# Teamcenter.Schemas.Soa._2006_03.Base.PolicyType
# Teamcenter.Schemas.Soa._2006_03.Base.Preferences
# Teamcenter.Schemas.Soa._2006_03.Base.PreferenceValue
# Teamcenter.Schemas.Soa._2006_03.Base.Preference
# Teamcenter.Schemas.Soa._2006_03.Base.PropDependant
# Teamcenter.Schemas.Soa._2006_03.Base.PropDescriptor
# Teamcenter.Schemas.Soa._2006_03.Base.PropertyNameValues
# Teamcenter.Schemas.Soa._2006_03.Base.PropertyValue
# Teamcenter.Schemas.Soa._2006_03.Base.Property
# Teamcenter.Schemas.Soa._2006_03.Base.RefId
# Teamcenter.Schemas.Soa._2006_03.Base.ServiceData
# Teamcenter.Schemas.Soa._2006_03.Base.TextInfo
# Teamcenter.Schemas.Soa._2006_03.Base.XJPropertyValue
# Teamcenter.Schemas.Soa._2006_03.Base.XJProperty
# Teamcenter.Schemas.Soa._2006_03.Exceptions.ConnectionException
# Teamcenter.Schemas.Soa._2006_03.Exceptions.InternalServerException
# Teamcenter.Schemas.Soa._2006_03.Exceptions.InvalidCredentialsException
# Teamcenter.Schemas.Soa._2006_03.Exceptions.InvalidUserException
# Teamcenter.Schemas.Soa._2006_03.Exceptions.ProtocolException
# Teamcenter.Schemas.Soa._2006_03.Exceptions.ServiceException
# Teamcenter.Schemas.Soa._2006_03.Exceptions.Error
# Teamcenter.Schemas.Soa._2006_03.Exceptions.SoaException
# Teamcenter.Services.Loose.Core.FileManagementRestBindingStub
# Teamcenter.Services.Loose.Core.FileManagementService
# Teamcenter.Services.Loose.Core.SessionRestBindingStub
# Teamcenter.Services.Loose.Core.SessionService
# Teamcenter.Services.Loose.Core._2023_12.Session.Session
# Teamcenter.Services.Loose.Core._2022_12.Session.Session
# Teamcenter.Services.Loose.Core._2021_12.Session.AddPoliciesResponse
# Teamcenter.Services.Loose.Core._2021_12.Session.Session
# Teamcenter.Services.Loose.Core._2019_06.Session.LicAdminInput
# Teamcenter.Services.Loose.Core._2019_06.Session.Session
# Teamcenter.Services.Loose.Core._2017_05.FileManagement.ReplaceFileInput
# Teamcenter.Services.Loose.Core._2017_05.FileManagement.FileManagement
# Teamcenter.Services.Loose.Core._2015_10.Session.Session
# Teamcenter.Services.Loose.Core._2015_10.FileManagement.DatasetDigestInfoResponse
# Teamcenter.Services.Loose.Core._2015_10.FileManagement.DigestInfo
# Teamcenter.Services.Loose.Core._2015_10.FileManagement.FileDigestInfoResponse
# Teamcenter.Services.Loose.Core._2015_10.FileManagement.FileDigestInfoSet
# Teamcenter.Services.Loose.Core._2015_10.FileManagement.FileManagement
# Teamcenter.Services.Loose.Core._2012_02.Session.RegisterIndex
# Teamcenter.Services.Loose.Core._2012_02.Session.SetPolicyResponse
# Teamcenter.Services.Loose.Core._2012_02.Session.Session
# Teamcenter.Services.Loose.Core._2011_06.Session.ClientCacheInfo
# Teamcenter.Services.Loose.Core._2011_06.Session.Credentials
# Teamcenter.Services.Loose.Core._2011_06.Session.Feature
# Teamcenter.Services.Loose.Core._2011_06.Session.LoginResponse
# Teamcenter.Services.Loose.Core._2011_06.Session.Session
# Teamcenter.Services.Loose.Core._2010_04.Session.GetShortcutsResponse
# Teamcenter.Services.Loose.Core._2010_04.Session.LHNNonTcObjectSectionComponent
# Teamcenter.Services.Loose.Core._2010_04.Session.LHNSectionComponents
# Teamcenter.Services.Loose.Core._2010_04.Session.LHNTcObjectSectionComponent
# Teamcenter.Services.Loose.Core._2010_04.Session.MultiPreferenceResponse2
# Teamcenter.Services.Loose.Core._2010_04.Session.ReturnedPreferences2
# Teamcenter.Services.Loose.Core._2010_04.Session.Session
# Teamcenter.Services.Loose.Core._2009_04.Session.Session
# Teamcenter.Services.Loose.Core._2008_06.Session.GetDisplayStringsOutput
# Teamcenter.Services.Loose.Core._2008_06.Session.GetDisplayStringsResponse
# Teamcenter.Services.Loose.Core._2008_06.Session.Session
# Teamcenter.Services.Loose.Core._2008_03.Session.ConnectResponse
# Teamcenter.Services.Loose.Core._2008_03.Session.FavoritesContainer
# Teamcenter.Services.Loose.Core._2008_03.Session.FavoritesList
# Teamcenter.Services.Loose.Core._2008_03.Session.FavoritesInfo
# Teamcenter.Services.Loose.Core._2008_03.Session.FavoritesObject
# Teamcenter.Services.Loose.Core._2008_03.Session.FavoritesResponse
# Teamcenter.Services.Loose.Core._2008_03.Session.Session
# Teamcenter.Services.Loose.Core._2007_12.Session.StateNameValue
# Teamcenter.Services.Loose.Core._2007_12.Session.Session
# Teamcenter.Services.Loose.Core._2007_06.Session.Session
# Teamcenter.Services.Loose.Core._2007_01.Session.GetTCSessionInfoResponse
# Teamcenter.Services.Loose.Core._2007_01.Session.MultiPreferencesResponse
# Teamcenter.Services.Loose.Core._2007_01.Session.ReturnedPreferences
# Teamcenter.Services.Loose.Core._2007_01.Session.ScopedPreferenceNames
# Teamcenter.Services.Loose.Core._2007_01.Session.TextInfo
# Teamcenter.Services.Loose.Core._2007_01.Session.Session
# Teamcenter.Services.Loose.Core._2007_01.FileManagement.GetTransientFileTicketsResponse
# Teamcenter.Services.Loose.Core._2007_01.FileManagement.TransientFileInfo
# Teamcenter.Services.Loose.Core._2007_01.FileManagement.TransientFileTicketInfo
# Teamcenter.Services.Loose.Core._2007_01.FileManagement.FileManagement
# Teamcenter.Services.Loose.Core._2006_03.Session.GetAvailableServicesResponse
# Teamcenter.Services.Loose.Core._2006_03.Session.GetGroupMembershipResponse
# Teamcenter.Services.Loose.Core._2006_03.Session.GetSessionGroupMemberResponse
# Teamcenter.Services.Loose.Core._2006_03.Session.LoginResponse
# Teamcenter.Services.Loose.Core._2006_03.Session.PreferencesResponse
# Teamcenter.Services.Loose.Core._2006_03.Session.PrefSetting
# Teamcenter.Services.Loose.Core._2006_03.Session.Session
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.CommitDatasetFileInfo
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.DatasetFileInfo
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.DatasetFileTicketInfo
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.FileTicketsResponse
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.GetDatasetWriteTicketsInputData
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.GetDatasetWriteTicketsResponse
# Teamcenter.Services.Loose.Core._2006_03.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core.FileManagementRestBindingStub
# Teamcenter.Services.Internal.Loose.Core.FileManagementService
# Teamcenter.Services.Internal.Loose.Core.SessionRestBindingStub
# Teamcenter.Services.Internal.Loose.Core.SessionService
# Teamcenter.Services.Internal.Loose.Core._2021_06.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core._2018_11.FileManagement.GetTransientTicketsDownloadInput
# Teamcenter.Services.Internal.Loose.Core._2018_11.FileManagement.GetTransientTicketsDownloadResponse
# Teamcenter.Services.Internal.Loose.Core._2018_11.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core._2017_05.FileManagement.DatashareManagerReplaceInfo
# Teamcenter.Services.Internal.Loose.Core._2017_05.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core._2014_11.Session.Session
# Teamcenter.Services.Internal.Loose.Core._2014_10.FileManagement.DatashareManagerDownloadInfo
# Teamcenter.Services.Internal.Loose.Core._2014_10.FileManagement.DatashareManagerUploadInfo
# Teamcenter.Services.Internal.Loose.Core._2014_10.FileManagement.GetPlmdFileTicketResponse
# Teamcenter.Services.Internal.Loose.Core._2014_10.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core._2010_09.FileManagement.CommitReplacedFileInfo
# Teamcenter.Services.Internal.Loose.Core._2010_09.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core._2008_06.Session.Session
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.CommitUploadedRegularFilesInput
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.CommitUploadedRegularFilesResponse
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.FileInfo
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.FileInfoTicket
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.FileTicketsResponse
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.GetRegularFileWriteTicketsInput
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.GetRegularFileWriteTicketsResponse
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.RegularFileInfo
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.WriteTicketsInput
# Teamcenter.Services.Internal.Loose.Core._2008_06.FileManagement.FileManagement
# Teamcenter.Services.Internal.Loose.Core._2008_03.Session.Session
# Teamcenter.Services.Internal.Loose.Core._2007_12.Session.Session
# Teamcenter.Services.Internal.Loose.Core._2007_05.Session.Session
# Teamcenter.Services.Internal.Loose.Core._2006_03.Types.Types
# Teamcenter.Soa.Internal.Utils.Helpers
# Teamcenter.Soa.Internal.Utils.HttpClient
# Teamcenter.Soa.Internal.Utils.HttpMethods
# Teamcenter.Soa.Internal.Client.ClientManager
# Teamcenter.Soa.Internal.Client.DigitalSignature
# Teamcenter.Soa.Internal.Client.DigitalSignatureIStream
# Teamcenter.Soa.Internal.Client.EventSharerImpl
# Teamcenter.Soa.Internal.Client.FMSWrapper
# Teamcenter.Soa.Internal.Client.FMSException
# Teamcenter.Soa.Internal.Client.FMSLoader
# Teamcenter.Soa.Internal.Client.HttpConfiguration
# Teamcenter.Soa.Internal.Client.HttpTransport
# Teamcenter.Soa.Internal.Client.JsonTunnelSender
# Teamcenter.Soa.Internal.Client.Log4NetRequestListener
# Teamcenter.Soa.Internal.Client.NotifyRequestListeners
# Teamcenter.Soa.Internal.Client.DynamicPolicy
# Teamcenter.Soa.Internal.Client.PolicyManager
# Teamcenter.Soa.Internal.Client.Sender
# Teamcenter.Soa.Internal.Client.ServiceRequestEnvelope
# Teamcenter.Soa.Internal.Client.ServiceResponseIStream
# Teamcenter.Soa.Internal.Client.SessionManager
# Teamcenter.Soa.Internal.Client.OldServerException
# Teamcenter.Soa.Internal.Client.TccsTransport
# Teamcenter.Soa.Internal.Client.Transport
# Teamcenter.Soa.Internal.Client.XmlRestSender
# Teamcenter.Soa.Internal.Client.Parse.CDMRootNode
# Teamcenter.Soa.Internal.Client.Parse.CDMStructNode
# Teamcenter.Soa.Internal.Client.Parse.MapArrayNode
# Teamcenter.Soa.Internal.Client.Parse.MapNode
# Teamcenter.Soa.Internal.Client.Parse.ModelObjectArrayNode
# Teamcenter.Soa.Internal.Client.Parse.ModelObjectNode
# Teamcenter.Soa.Internal.Client.Parse.NamedValue
# Teamcenter.Soa.Internal.Client.Parse.NamespaceMapper
# Teamcenter.Soa.Internal.Client.Parse.Node
# Teamcenter.Soa.Internal.Client.Parse.ParameterTypes
# Teamcenter.Soa.Internal.Client.Parse.PolicyNode
# Teamcenter.Soa.Internal.Client.Parse.PrimitiveArrayNode
# Teamcenter.Soa.Internal.Client.Parse.PrimitiveNode
# Teamcenter.Soa.Internal.Client.Parse.StringNode
# Teamcenter.Soa.Internal.Client.Parse.BooleanNode
# Teamcenter.Soa.Internal.Client.Parse.IntegerNode
# Teamcenter.Soa.Internal.Client.Parse.FloatNode
# Teamcenter.Soa.Internal.Client.Parse.DoubleNode
# Teamcenter.Soa.Internal.Client.Parse.DateNode
# Teamcenter.Soa.Internal.Client.Parse.PrimitiveRootNode
# Teamcenter.Soa.Internal.Client.Parse.Primitives
# Teamcenter.Soa.Internal.Client.Parse.ReflectionParser
# Teamcenter.Soa.Internal.Client.Parse.ReflectionWriter
# Teamcenter.Soa.Internal.Client.Parse.StructArrayNode
# Teamcenter.Soa.Internal.Client.Parse.StructRootNode
# Teamcenter.Soa.Internal.Client.Parse.FieldNode
# Teamcenter.Soa.Internal.Client.Parse.StructNode
# Teamcenter.Soa.Internal.Client.Parse.StubNode
# Teamcenter.Soa.Internal.Client.Parse.XMLElement
# Teamcenter.Soa.Internal.Client.Parse.XMLNamespace
# Teamcenter.Soa.Internal.Client.Model.ActionReferenceImpl
# Teamcenter.Soa.Internal.Client.Model.BasedOnImpl
# Teamcenter.Soa.Internal.Client.Model.CachedClientMetaModel
# Teamcenter.Soa.Internal.Client.Model.CachelessClientMetaModel
# Teamcenter.Soa.Internal.Client.Model.Choice`1
# Teamcenter.Soa.Internal.Client.Model.ConditionResolver
# Teamcenter.Soa.Internal.Client.Model.DatasetTypeImpl
# Teamcenter.Soa.Internal.Client.Model.DefaultClientDataModel
# Teamcenter.Soa.Internal.Client.Model.DefaultClientMetaModel
# Teamcenter.Soa.Internal.Client.Model.DefaultObjectFactory
# Teamcenter.Soa.Internal.Client.Model.DynamicLov
# Teamcenter.Soa.Internal.Client.Model.DynamicLovInfo
# Teamcenter.Soa.Internal.Client.Model.DynamicLovValues
# Teamcenter.Soa.Internal.Client.Model.JavaStyleStringCompare
# Teamcenter.Soa.Internal.Client.Model.ErrorStackImpl
# Teamcenter.Soa.Internal.Client.Model.ErrorValueImpl
# Teamcenter.Soa.Internal.Client.Model.FmsErrorStackImpl
# Teamcenter.Soa.Internal.Client.Model.LooseObjectFactory
# Teamcenter.Soa.Internal.Client.Model.LovImpl
# Teamcenter.Soa.Internal.Client.Model.LovInfoImpl
# Teamcenter.Soa.Internal.Client.Model.LovValueImpl
# Teamcenter.Soa.Internal.Client.Model.ModelLock
# Teamcenter.Soa.Internal.Client.Model.ClassNames
# Teamcenter.Soa.Internal.Client.Model.ModelManagerImpl
# Teamcenter.Soa.Internal.Client.Model.ModelObjectImpl
# Teamcenter.Soa.Internal.Client.Model.NamingRuleImpl
# Teamcenter.Soa.Internal.Client.Model.PartialErrorsImpl
# Teamcenter.Soa.Internal.Client.Model.PopulateModel
# Teamcenter.Soa.Internal.Client.Model.PreferencesImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyArrayValue`1
# Teamcenter.Soa.Internal.Client.Model.PropertyBoolArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyBoolImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyCharArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyCharImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyDateArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyDateImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyDescriptionImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyDoubleArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyDoubleImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyFloatArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyFloatImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyIntArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyIntImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyModelObjectArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyModelObjectImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyShortArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyShortImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyStringArrayImpl
# Teamcenter.Soa.Internal.Client.Model.PropertyStringImpl
# Teamcenter.Soa.Internal.Client.Model.ReferenceImpl
# Teamcenter.Soa.Internal.Client.Model.RevNameRuleImpl
# Teamcenter.Soa.Internal.Client.Model.RulePatternImpl
# Teamcenter.Soa.Internal.Client.Model.ServiceDataImpl
# Teamcenter.Soa.Internal.Client.Model.SoaTypeImpl
# Teamcenter.Soa.Internal.Client.Model.TcServerDate
# Teamcenter.Soa.Internal.Client.Model.ToolActionImpl
# Teamcenter.Soa.Internal.Client.Model.ToolImpl
# Teamcenter.Soa.Internal.Client.Model.TypeCache
# Teamcenter.Soa.Client.AbstractCredentialManager
# Teamcenter.Soa.Client.Connection
# Teamcenter.Soa.Client.CredentialManager
# Teamcenter.Soa.Client.SponsoredCredentials
# Teamcenter.Soa.Client.DefaultExceptionHandler
# Teamcenter.Soa.Client.EventSharer
# Teamcenter.Soa.Client.ExceptionHandler
# Teamcenter.Soa.Client.FMS_Progress_Callback
# Teamcenter.Soa.Client.FileManagementUtility
# Teamcenter.Soa.Client.GetFileResponse
# Teamcenter.Soa.Client.FSCStreamingUtility
# Teamcenter.Soa.Client.PolicyStyle
# Teamcenter.Soa.Client.ObjectPropertyPolicyManager
# Teamcenter.Soa.Client.PKCS7
# Teamcenter.Soa.Client.ServiceInfo
# Teamcenter.Soa.Client.RequestListener
# Teamcenter.Soa.Client.SessionHandler
# Teamcenter.Soa.Client.SponsoredSsoCredentials
# Teamcenter.Soa.Client.SsoCredentials
# Teamcenter.Soa.Client.TccsEnvInfo
# Teamcenter.Soa.Client.Model.ActionReference
# Teamcenter.Soa.Client.Model.BasedOn
# Teamcenter.Soa.Client.Model.ChangeListener
# Teamcenter.Soa.Client.Model.ClientDataModel
# Teamcenter.Soa.Client.Model.ClientMetaModel
# Teamcenter.Soa.Client.Model.ConditionChoices`1
# Teamcenter.Soa.Client.Model.CreateInput
# Teamcenter.Soa.Client.Model.CreateListener
# Teamcenter.Soa.Client.Model.DatasetType
# Teamcenter.Soa.Client.Model.DeleteListener
# Teamcenter.Soa.Client.Model.ErrorStack
# Teamcenter.Soa.Client.Model.ErrorValue
# Teamcenter.Soa.Client.Model.Style
# Teamcenter.Soa.Client.Model.Lov
# Teamcenter.Soa.Client.Model.Usage
# Teamcenter.Soa.Client.Model.LovInfo
# Teamcenter.Soa.Client.Model.LovValue
# Teamcenter.Soa.Client.Model.ModelEventListener
# Teamcenter.Soa.Client.Model.ModelManager
# Teamcenter.Soa.Client.Model.ModelObject
# Teamcenter.Soa.Client.Model.ModelObjectFactory
# Teamcenter.Soa.Client.Model.RuleCase
# Teamcenter.Soa.Client.Model.NamingRule
# Teamcenter.Soa.Client.Model.NullModelObject
# Teamcenter.Soa.Client.Model.ObjectFactory
# Teamcenter.Soa.Client.Model.PartialErrorListener
# Teamcenter.Soa.Client.Model.PartialErrors
# Teamcenter.Soa.Client.Model.Preferences
# Teamcenter.Soa.Client.Model.Property
# Teamcenter.Soa.Client.Model.PropertyValueType
# Teamcenter.Soa.Client.Model.PropertyValueServerType
# Teamcenter.Soa.Client.Model.PropertyType
# Teamcenter.Soa.Client.Model.PropertyFieldType
# Teamcenter.Soa.Client.Model.LovCategory
# Teamcenter.Soa.Client.Model.PropertyConstants
# Teamcenter.Soa.Client.Model.RuleCategory
# Teamcenter.Soa.Client.Model.PropertyDescription
# Teamcenter.Soa.Client.Model.Reference
# Teamcenter.Soa.Client.Model.RuleType
# Teamcenter.Soa.Client.Model.AlphabeticCase
# Teamcenter.Soa.Client.Model.SupplementalRuleType
# Teamcenter.Soa.Client.Model.RevNameRule
# Teamcenter.Soa.Client.Model.RulePattern
# Teamcenter.Soa.Client.Model.ServiceData
# Teamcenter.Soa.Client.Model.TypeConstants
# Teamcenter.Soa.Client.Model.RevisionRuleCategory
# Teamcenter.Soa.Client.Model.SoaType
# Teamcenter.Soa.Client.Model.Tool
# Teamcenter.Soa.Client.Model.ToolAction
# Teamcenter.Soa.Internal.Client.ClientManager+ClientInfo
# Teamcenter.Soa.Internal.Client.DigitalSignature+Algorithm
# Teamcenter.Soa.Internal.Client.Log4NetRequestListener+RequestData
# Teamcenter.Soa.Internal.Client.Parse.MapNode+KeyOrValue
# Teamcenter.Soa.Internal.Client.Parse.Node+Context
# Teamcenter.Soa.Internal.Client.Parse.StubNode+MOStub
# Teamcenter.Soa.Internal.Client.Parse.StubNode+AnyStub
# Teamcenter.Soa.Internal.Client.Parse.StubNode+FieldStub
# Teamcenter.Soa.Internal.Client.Parse.StubNode+ArrayStub
# Teamcenter.Soa.Internal.Client.Parse.StubNode+KeyValueStub
# Teamcenter.Soa.Internal.Client.Parse.StubNode+MapStub
# Teamcenter.Soa.Internal.Client.Model.FmsErrorStackImpl+FmsErrorValue
# Teamcenter.Soa.Client.Connection+ListenerNotifier
# Teamcenter.Soa.Client.FileManagementUtility+FmsServiceData
# Teamcenter.Soa.Client.FSCStreamingUtility+FmsServiceData
# Teamcenter.Soa.Client.FSCStreamingUtility+ValidationResult
# Teamcenter.Net.TcServerProxy.Crypto.PKCS7
# Teamcenter.Net.TcServerProxy.Client.AuthScope
# Teamcenter.Net.TcServerProxy.Client.Credential
# Teamcenter.Net.TcServerProxy.Client.CredentialProvider
# Teamcenter.Net.TcServerProxy.Client.CredentialsUnavailableException
# Teamcenter.Net.TcServerProxy.Client.TcServerRequestWrapper
# Teamcenter.Net.TcServerProxy.Client.NetBindingLoader
# Teamcenter.Net.TcServerProxy.Client.TSPConnectionException
# Teamcenter.Net.TcServerProxy.Client.TSPException
# Teamcenter.Net.TcServerProxy.Client.TSPProtocolException
# Teamcenter.Net.TcServerProxy.Client.TSPRuntimeException
# Teamcenter.Net.TcServerProxy.Client.TSPSession
# Teamcenter.Net.TcServerProxy.Client.TSPUnrecognisedException
# Teamcenter.Net.TcServerProxy.Admin.Environment
# Teamcenter.Net.TcServerProxy.Admin.EnvironmentInfoWrapper
# Teamcenter.Net.TcServerProxy.Admin.Service
# Teamcenter.Soa.Client.Model.StrongObjectFactoryAbr0advancedbomrollup
# Teamcenter.Soa.Client.Model.Strong.Abr0RollupReportsProvider
# Teamcenter.Soa.Client.Model.Strong.Abr0RollupTemplatesProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactory
# Teamcenter.Soa.Client.Model.Strong.AbsOccArchRef
# Teamcenter.Soa.Client.Model.Strong.AbsOccChildItem
# Teamcenter.Soa.Client.Model.Strong.AbsOccData
# Teamcenter.Soa.Client.Model.Strong.AbsOccDataQualifier
# Teamcenter.Soa.Client.Model.Strong.AbsOccFlags
# Teamcenter.Soa.Client.Model.Strong.AbsOccGdeObject
# Teamcenter.Soa.Client.Model.Strong.AbsOccGrmAnchor
# Teamcenter.Soa.Client.Model.Strong.AbsOccInstanceNo
# Teamcenter.Soa.Client.Model.Strong.AbsOccName
# Teamcenter.Soa.Client.Model.Strong.AbsOccNote
# Teamcenter.Soa.Client.Model.Strong.AbsOccPosRef
# Teamcenter.Soa.Client.Model.Strong.AbsOccQuantity
# Teamcenter.Soa.Client.Model.Strong.AbsOccRefDesignator
# Teamcenter.Soa.Client.Model.Strong.AbsOccSeqNo
# Teamcenter.Soa.Client.Model.Strong.AbsOccSource
# Teamcenter.Soa.Client.Model.Strong.AbsOccType
# Teamcenter.Soa.Client.Model.Strong.AbsOccUCC
# Teamcenter.Soa.Client.Model.Strong.AbsOccUOM
# Teamcenter.Soa.Client.Model.Strong.AbsOccurrence
# Teamcenter.Soa.Client.Model.Strong.AbsOccUsgPartID
# Teamcenter.Soa.Client.Model.Strong.AbsOccUsgProduct
# Teamcenter.Soa.Client.Model.Strong.AbsOccVariantCondition
# Teamcenter.Soa.Client.Model.Strong.AbsOccViewQualifier
# Teamcenter.Soa.Client.Model.Strong.AbsOccXform
# Teamcenter.Soa.Client.Model.Strong.ADA_License
# Teamcenter.Soa.Client.Model.Strong.AdobeIllustrator
# Teamcenter.Soa.Client.Model.Strong.AdobeInDesign
# Teamcenter.Soa.Client.Model.Strong.AIEBatchOperation
# Teamcenter.Soa.Client.Model.Strong.AIEComponentInfo
# Teamcenter.Soa.Client.Model.Strong.AIEConnection
# Teamcenter.Soa.Client.Model.Strong.AIEConnectionAssocFile
# Teamcenter.Soa.Client.Model.Strong.AIEConnectionFile
# Teamcenter.Soa.Client.Model.Strong.AIEConnectionFileList
# Teamcenter.Soa.Client.Model.Strong.AIEConnectionXdataFile
# Teamcenter.Soa.Client.Model.Strong.AIEDatasetInfo
# Teamcenter.Soa.Client.Model.Strong.AIEEncapsulation
# Teamcenter.Soa.Client.Model.Strong.AIEExportAssembly
# Teamcenter.Soa.Client.Model.Strong.AIEExportNode
# Teamcenter.Soa.Client.Model.Strong.AIEExportOperation
# Teamcenter.Soa.Client.Model.Strong.AIEImportOperation
# Teamcenter.Soa.Client.Model.Strong.AIEPersistentConnection
# Teamcenter.Soa.Client.Model.Strong.AIERootObject
# Teamcenter.Soa.Client.Model.Strong.Allocation
# Teamcenter.Soa.Client.Model.Strong.AllocationData
# Teamcenter.Soa.Client.Model.Strong.AllocationLine
# Teamcenter.Soa.Client.Model.Strong.AllocationMap
# Teamcenter.Soa.Client.Model.Strong.AllocationMapMaster
# Teamcenter.Soa.Client.Model.Strong.AllocationMapRevision
# Teamcenter.Soa.Client.Model.Strong.AllocationMapRevision_Master
# Teamcenter.Soa.Client.Model.Strong.AllocationMapRevMaster
# Teamcenter.Soa.Client.Model.Strong.AllocationMap_Master
# Teamcenter.Soa.Client.Model.Strong.AllocationWindow
# Teamcenter.Soa.Client.Model.Strong.AM_ACE
# Teamcenter.Soa.Client.Model.Strong.AM_ACL
# Teamcenter.Soa.Client.Model.Strong.AM_named_tag
# Teamcenter.Soa.Client.Model.Strong.AM_privileges
# Teamcenter.Soa.Client.Model.Strong.AM_tree
# Teamcenter.Soa.Client.Model.Strong.Anchor
# Teamcenter.Soa.Client.Model.Strong.ANDList
# Teamcenter.Soa.Client.Model.Strong.APNSymLink
# Teamcenter.Soa.Client.Model.Strong.AppDataModelDefinition
# Teamcenter.Soa.Client.Model.Strong.AppearanceGroup
# Teamcenter.Soa.Client.Model.Strong.AppearancesSearchResult
# Teamcenter.Soa.Client.Model.Strong.AppExtensionPoint
# Teamcenter.Soa.Client.Model.Strong.AppExtensionRule
# Teamcenter.Soa.Client.Model.Strong.AppExtensionRuleType
# Teamcenter.Soa.Client.Model.Strong.AppGroupBOPLine
# Teamcenter.Soa.Client.Model.Strong.AppInterface
# Teamcenter.Soa.Client.Model.Strong.AppInterfaceType
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteria
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaAttribute
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaBoxZone
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaGroup
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaInClass
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaMapAttr
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaNamedZone
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaPlaneZone
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaProximity
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaSavedQry
# Teamcenter.Soa.Client.Model.Strong.ApprSearchCriteriaSlctState
# Teamcenter.Soa.Client.Model.Strong.Architecture
# Teamcenter.Soa.Client.Model.Strong.ArchitectureMaster
# Teamcenter.Soa.Client.Model.Strong.ArchitectureRevision
# Teamcenter.Soa.Client.Model.Strong.ArchitectureRevision_Master
# Teamcenter.Soa.Client.Model.Strong.ArchitectureVersionMaster
# Teamcenter.Soa.Client.Model.Strong.Architecture_Master
# Teamcenter.Soa.Client.Model.Strong.ArcWeld
# Teamcenter.Soa.Client.Model.Strong.ArcWeldFormClass
# Teamcenter.Soa.Client.Model.Strong.ArcWeldMaster
# Teamcenter.Soa.Client.Model.Strong.ArcWeldRevision
# Teamcenter.Soa.Client.Model.Strong.ArcWeldRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.ArcWeldRevision_Master
# Teamcenter.Soa.Client.Model.Strong.ArcWeld_Attribute_Form
# Teamcenter.Soa.Client.Model.Strong.ArcWeld_Master
# Teamcenter.Soa.Client.Model.Strong.AssemblyArrangement
# Teamcenter.Soa.Client.Model.Strong.AssemblyArrangementAnchor
# Teamcenter.Soa.Client.Model.Strong.AuditDefinition
# Teamcenter.Soa.Client.Model.Strong.AuditLine
# Teamcenter.Soa.Client.Model.Strong.AuditLog
# Teamcenter.Soa.Client.Model.Strong.AuditReport
# Teamcenter.Soa.Client.Model.Strong.Authorization
# Teamcenter.Soa.Client.Model.Strong.AuthorizationRule
# Teamcenter.Soa.Client.Model.Strong.BillRate
# Teamcenter.Soa.Client.Model.Strong.Bitmap
# Teamcenter.Soa.Client.Model.Strong.Bitmap_Thumbnail
# Teamcenter.Soa.Client.Model.Strong.Bldb0
# Teamcenter.Soa.Client.Model.Strong.Bldb1
# Teamcenter.Soa.Client.Model.Strong.BMOperation
# Teamcenter.Soa.Client.Model.Strong.BomChange
# Teamcenter.Soa.Client.Model.Strong.BomChangeSampleFSC
# Teamcenter.Soa.Client.Model.Strong.BomChange_Form
# Teamcenter.Soa.Client.Model.Strong.BOMDerivedDefault
# Teamcenter.Soa.Client.Model.Strong.BOMFixedDefault
# Teamcenter.Soa.Client.Model.Strong.BOMLine
# Teamcenter.Soa.Client.Model.Strong.BOMOption
# Teamcenter.Soa.Client.Model.Strong.BOMOptionIndexExpr
# Teamcenter.Soa.Client.Model.Strong.BOMRuleCheck
# Teamcenter.Soa.Client.Model.Strong.BOMVariantExprBlock
# Teamcenter.Soa.Client.Model.Strong.BOMVariantRule
# Teamcenter.Soa.Client.Model.Strong.BOMView
# Teamcenter.Soa.Client.Model.Strong.BOMView_Revision
# Teamcenter.Soa.Client.Model.Strong.BOMWindow
# Teamcenter.Soa.Client.Model.Strong.BOM_Rollup
# Teamcenter.Soa.Client.Model.Strong.BOPWindow
# Teamcenter.Soa.Client.Model.Strong.BOSLine
# Teamcenter.Soa.Client.Model.Strong.BOSWindow
# Teamcenter.Soa.Client.Model.Strong.BoundingBox
# Teamcenter.Soa.Client.Model.Strong.BoundingMultiBox
# Teamcenter.Soa.Client.Model.Strong.Briefcase
# Teamcenter.Soa.Client.Model.Strong.BulkCopyInput
# Teamcenter.Soa.Client.Model.Strong.BulkData
# Teamcenter.Soa.Client.Model.Strong.BulkInput
# Teamcenter.Soa.Client.Model.Strong.BulkSaveInput
# Teamcenter.Soa.Client.Model.Strong.BusinessContext
# Teamcenter.Soa.Client.Model.Strong.BusinessElement
# Teamcenter.Soa.Client.Model.Strong.BusinessObject
# Teamcenter.Soa.Client.Model.Strong.BusinessObjectInterface
# Teamcenter.Soa.Client.Model.Strong.BusinessRule
# Teamcenter.Soa.Client.Model.Strong.BusinessRuleDescriptor
# Teamcenter.Soa.Client.Model.Strong.BVRSyncInfo
# Teamcenter.Soa.Client.Model.Strong.BVRSyncInfoStorage
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefinition
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefPart
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefPartGRM
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefPartICS
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefPartNR
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefPartProp
# Teamcenter.Soa.Client.Model.Strong.CadAttrMappingDefPartSNoff
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysis
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysisDS
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysisMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysisRevision
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysisRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysisRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEAnalysis_Master
# Teamcenter.Soa.Client.Model.Strong.CAEAttachmentWindow
# Teamcenter.Soa.Client.Model.Strong.CAEBC
# Teamcenter.Soa.Client.Model.Strong.CAEBCItem
# Teamcenter.Soa.Client.Model.Strong.CAEBCItemMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEBCItemRevision
# Teamcenter.Soa.Client.Model.Strong.CAEBCItemRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAEBCItemRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEBCItem_Master
# Teamcenter.Soa.Client.Model.Strong.CAEConn
# Teamcenter.Soa.Client.Model.Strong.CAEConnItem
# Teamcenter.Soa.Client.Model.Strong.CAEConnItemMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEConnItemRevision
# Teamcenter.Soa.Client.Model.Strong.CAEConnItemRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAEConnItemRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEConnItem_Master
# Teamcenter.Soa.Client.Model.Strong.CAEGeom
# Teamcenter.Soa.Client.Model.Strong.CAEGeometry
# Teamcenter.Soa.Client.Model.Strong.CAEGeometryMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEGeometryRevision
# Teamcenter.Soa.Client.Model.Strong.CAEGeometryRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAEGeometryRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEGeometry_Master
# Teamcenter.Soa.Client.Model.Strong.CAEItem
# Teamcenter.Soa.Client.Model.Strong.CAEItemRevision
# Teamcenter.Soa.Client.Model.Strong.CAELoad
# Teamcenter.Soa.Client.Model.Strong.CAELoadItem
# Teamcenter.Soa.Client.Model.Strong.CAELoadItemMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAELoadItemRevision
# Teamcenter.Soa.Client.Model.Strong.CAELoadItemRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAELoadItemRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAELoadItem_Master
# Teamcenter.Soa.Client.Model.Strong.CAEMapRow
# Teamcenter.Soa.Client.Model.Strong.CAEMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEMesh
# Teamcenter.Soa.Client.Model.Strong.CAEModel
# Teamcenter.Soa.Client.Model.Strong.CAEModelMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEModelRevision
# Teamcenter.Soa.Client.Model.Strong.CAEModelRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAEModelRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEModel_Master
# Teamcenter.Soa.Client.Model.Strong.CAEResult
# Teamcenter.Soa.Client.Model.Strong.CAEResultData
# Teamcenter.Soa.Client.Model.Strong.CAEResultMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEResultRevision
# Teamcenter.Soa.Client.Model.Strong.CAEResultRevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAEResultRevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAEResults
# Teamcenter.Soa.Client.Model.Strong.CAEResult_Master
# Teamcenter.Soa.Client.Model.Strong.CAERevision_Master
# Teamcenter.Soa.Client.Model.Strong.CAERevMasterStore
# Teamcenter.Soa.Client.Model.Strong.CAESolution
# Teamcenter.Soa.Client.Model.Strong.CAESolver
# Teamcenter.Soa.Client.Model.Strong.CAESolverManager
# Teamcenter.Soa.Client.Model.Strong.CAESolverManagerStore
# Teamcenter.Soa.Client.Model.Strong.CAEStructureMap
# Teamcenter.Soa.Client.Model.Strong.CAE_AIF_Form
# Teamcenter.Soa.Client.Model.Strong.CAE_Master
# Teamcenter.Soa.Client.Model.Strong.CallbackFunction
# Teamcenter.Soa.Client.Model.Strong.CCObject
# Teamcenter.Soa.Client.Model.Strong.CfgAbsOccAttachmentLine
# Teamcenter.Soa.Client.Model.Strong.CfgActivityLine
# Teamcenter.Soa.Client.Model.Strong.CfgAttachmentLine
# Teamcenter.Soa.Client.Model.Strong.CfgAttachmentWindow
# Teamcenter.Soa.Client.Model.Strong.CfgBlAttachmentLine
# Teamcenter.Soa.Client.Model.Strong.CFMDateEntry
# Teamcenter.Soa.Client.Model.Strong.CFMEndItemEntry
# Teamcenter.Soa.Client.Model.Strong.CFMGroupEntry
# Teamcenter.Soa.Client.Model.Strong.CFMGroupItemTypeEntry
# Teamcenter.Soa.Client.Model.Strong.CFMLatestEntry
# Teamcenter.Soa.Client.Model.Strong.CFMOverrideEntry
# Teamcenter.Soa.Client.Model.Strong.CFMPreciseEntry
# Teamcenter.Soa.Client.Model.Strong.CFMRuleEntry
# Teamcenter.Soa.Client.Model.Strong.CFMStatusEntry
# Teamcenter.Soa.Client.Model.Strong.CFMUnitNoEntry
# Teamcenter.Soa.Client.Model.Strong.CFMWorkingEntry
# Teamcenter.Soa.Client.Model.Strong.CFM_configuration_object
# Teamcenter.Soa.Client.Model.Strong.CFM_date_info
# Teamcenter.Soa.Client.Model.Strong.ChangeNotificationData
# Teamcenter.Soa.Client.Model.Strong.ChangeOrderData
# Teamcenter.Soa.Client.Model.Strong.ChangeProposalData
# Teamcenter.Soa.Client.Model.Strong.ChangeReviewData
# Teamcenter.Soa.Client.Model.Strong.ChangeTypeData
# Teamcenter.Soa.Client.Model.Strong.Change_Order
# Teamcenter.Soa.Client.Model.Strong.ChargeList
# Teamcenter.Soa.Client.Model.Strong.CheckListSample
# Teamcenter.Soa.Client.Model.Strong.Checklist_Template_Form
# Teamcenter.Soa.Client.Model.Strong.ClearanceDBConnection
# Teamcenter.Soa.Client.Model.Strong.ClearanceDBReport
# Teamcenter.Soa.Client.Model.Strong.ClearanceResults
# Teamcenter.Soa.Client.Model.Strong.ClearanceResultsFilter
# Teamcenter.Soa.Client.Model.Strong.ClientDataMaster
# Teamcenter.Soa.Client.Model.Strong.CLIPS
# Teamcenter.Soa.Client.Model.Strong.CloneStructureCADDependencyData
# Teamcenter.Soa.Client.Model.Strong.CloneStructureTopLineData
# Teamcenter.Soa.Client.Model.Strong.ClosureRule
# Teamcenter.Soa.Client.Model.Strong.CMBaseRevRuleForm
# Teamcenter.Soa.Client.Model.Strong.CME_Report
# Teamcenter.Soa.Client.Model.Strong.CMIDNum
# Teamcenter.Soa.Client.Model.Strong.CMIICNFormClass
# Teamcenter.Soa.Client.Model.Strong.CMIICRFormClass
# Teamcenter.Soa.Client.Model.Strong.CMII_CN_Form
# Teamcenter.Soa.Client.Model.Strong.CMII_CR_Form
# Teamcenter.Soa.Client.Model.Strong.CMList
# Teamcenter.Soa.Client.Model.Strong.CMMV_transform
# Teamcenter.Soa.Client.Model.Strong.CMSForm
# Teamcenter.Soa.Client.Model.Strong.CMState
# Teamcenter.Soa.Client.Model.Strong.CM_0_LIST_alt
# Teamcenter.Soa.Client.Model.Strong.CM_Base_Configuration
# Teamcenter.Soa.Client.Model.Strong.CM_Context
# Teamcenter.Soa.Client.Model.Strong.CM_Context_Job
# Teamcenter.Soa.Client.Model.Strong.CM_Context_Routing
# Teamcenter.Soa.Client.Model.Strong.CM_CR_approver_list
# Teamcenter.Soa.Client.Model.Strong.CM_decision
# Teamcenter.Soa.Client.Model.Strong.CM_Default_Order_Data
# Teamcenter.Soa.Client.Model.Strong.CM_Default_Proposal_Data
# Teamcenter.Soa.Client.Model.Strong.CM_list
# Teamcenter.Soa.Client.Model.Strong.CM_Package
# Teamcenter.Soa.Client.Model.Strong.CM_Routing_Slips
# Teamcenter.Soa.Client.Model.Strong.CM_SETUP
# Teamcenter.Soa.Client.Model.Strong.CM_Setup_routing
# Teamcenter.Soa.Client.Model.Strong.CM_state
# Teamcenter.Soa.Client.Model.Strong.CNAppDList
# Teamcenter.Soa.Client.Model.Strong.CNDList
# Teamcenter.Soa.Client.Model.Strong.CNForm
# Teamcenter.Soa.Client.Model.Strong.CNRevDList
# Teamcenter.Soa.Client.Model.Strong.CNRForm
# Teamcenter.Soa.Client.Model.Strong.COForm
# Teamcenter.Soa.Client.Model.Strong.Company
# Teamcenter.Soa.Client.Model.Strong.CompanyContact
# Teamcenter.Soa.Client.Model.Strong.CompanyLocation
# Teamcenter.Soa.Client.Model.Strong.CompanyMaster
# Teamcenter.Soa.Client.Model.Strong.CompanyMasterS
# Teamcenter.Soa.Client.Model.Strong.CompanyRevision
# Teamcenter.Soa.Client.Model.Strong.CompanyRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CompanyRevMasterS
# Teamcenter.Soa.Client.Model.Strong.ComponentRelation
# Teamcenter.Soa.Client.Model.Strong.CompositionContext
# Teamcenter.Soa.Client.Model.Strong.Condition
# Teamcenter.Soa.Client.Model.Strong.ConditionParameter
# Teamcenter.Soa.Client.Model.Strong.ConditionSignature
# Teamcenter.Soa.Client.Model.Strong.CondValAgent
# Teamcenter.Soa.Client.Model.Strong.CondValAgentMaster
# Teamcenter.Soa.Client.Model.Strong.CondValAgentMasterS
# Teamcenter.Soa.Client.Model.Strong.CondValAgentRevision
# Teamcenter.Soa.Client.Model.Strong.CondValAgentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CondValAgentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.CondValData
# Teamcenter.Soa.Client.Model.Strong.CondValDataMaster
# Teamcenter.Soa.Client.Model.Strong.CondValDataMasterS
# Teamcenter.Soa.Client.Model.Strong.CondValDataRevision
# Teamcenter.Soa.Client.Model.Strong.CondValDataRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CondValDataRevMasterS
# Teamcenter.Soa.Client.Model.Strong.CondValResult
# Teamcenter.Soa.Client.Model.Strong.ConfigurationCNF
# Teamcenter.Soa.Client.Model.Strong.ConfigurationContext
# Teamcenter.Soa.Client.Model.Strong.ConfigurationExprLiteral
# Teamcenter.Soa.Client.Model.Strong.ConfigurationFamily
# Teamcenter.Soa.Client.Model.Strong.ConfiguredTechnicalPortfolio
# Teamcenter.Soa.Client.Model.Strong.Connection
# Teamcenter.Soa.Client.Model.Strong.ConnectionMaster
# Teamcenter.Soa.Client.Model.Strong.ConnectionRevision
# Teamcenter.Soa.Client.Model.Strong.ConnectionRevision_Master
# Teamcenter.Soa.Client.Model.Strong.ConnectionRevMaster
# Teamcenter.Soa.Client.Model.Strong.Connection_Master
# Teamcenter.Soa.Client.Model.Strong.Connection_Terminal
# Teamcenter.Soa.Client.Model.Strong.Connection_TerminalStorage
# Teamcenter.Soa.Client.Model.Strong.Constant
# Teamcenter.Soa.Client.Model.Strong.ConstantAttach
# Teamcenter.Soa.Client.Model.Strong.ConstantChoice
# Teamcenter.Soa.Client.Model.Strong.Constituent
# Teamcenter.Soa.Client.Model.Strong.ConstituentMaster
# Teamcenter.Soa.Client.Model.Strong.ConstituentMasterS
# Teamcenter.Soa.Client.Model.Strong.ConstituentRevision
# Teamcenter.Soa.Client.Model.Strong.ConstituentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.ConstituentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.ContactInCompany
# Teamcenter.Soa.Client.Model.Strong.ContentStorage
# Teamcenter.Soa.Client.Model.Strong.CORAppDList
# Teamcenter.Soa.Client.Model.Strong.CORCoreDList
# Teamcenter.Soa.Client.Model.Strong.CORForm
# Teamcenter.Soa.Client.Model.Strong.CostDataClass
# Teamcenter.Soa.Client.Model.Strong.CostDataForm
# Teamcenter.Soa.Client.Model.Strong.CostValue
# Teamcenter.Soa.Client.Model.Strong.CostValue_Relation
# Teamcenter.Soa.Client.Model.Strong.CO_ITEM_REVISION
# Teamcenter.Soa.Client.Model.Strong.CO_Package
# Teamcenter.Soa.Client.Model.Strong.CO_REFERENCE
# Teamcenter.Soa.Client.Model.Strong.CO_WHERE_USED
# Teamcenter.Soa.Client.Model.Strong.CPBrief
# Teamcenter.Soa.Client.Model.Strong.CPBriefMaster
# Teamcenter.Soa.Client.Model.Strong.CPBriefMasterS
# Teamcenter.Soa.Client.Model.Strong.CPBriefRevision
# Teamcenter.Soa.Client.Model.Strong.CPBriefRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CPBriefRevMasterS
# Teamcenter.Soa.Client.Model.Strong.CPForm
# Teamcenter.Soa.Client.Model.Strong.CPMarketingBrief
# Teamcenter.Soa.Client.Model.Strong.CPMarketingBriefMaster
# Teamcenter.Soa.Client.Model.Strong.CPMarketingBriefMasterS
# Teamcenter.Soa.Client.Model.Strong.CPMarketingBriefRevision
# Teamcenter.Soa.Client.Model.Strong.CPMarketingBriefRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CPMarketingBriefRevMasterS
# Teamcenter.Soa.Client.Model.Strong.CPProductRough
# Teamcenter.Soa.Client.Model.Strong.CPProductRoughMaster
# Teamcenter.Soa.Client.Model.Strong.CPProductRoughMasterS
# Teamcenter.Soa.Client.Model.Strong.CPProductRoughRevision
# Teamcenter.Soa.Client.Model.Strong.CPProductRoughRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CPProductRoughRevMasterS
# Teamcenter.Soa.Client.Model.Strong.CPRAppDList
# Teamcenter.Soa.Client.Model.Strong.CPRCoreDList
# Teamcenter.Soa.Client.Model.Strong.CPRForm
# Teamcenter.Soa.Client.Model.Strong.CPThemeBoard
# Teamcenter.Soa.Client.Model.Strong.CPThemeBoardMaster
# Teamcenter.Soa.Client.Model.Strong.CPThemeBoardMasterS
# Teamcenter.Soa.Client.Model.Strong.CPThemeBoardRevision
# Teamcenter.Soa.Client.Model.Strong.CPThemeBoardRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.CPThemeBoardRevMasterS
# Teamcenter.Soa.Client.Model.Strong.CP_Has_ThemeBoard
# Teamcenter.Soa.Client.Model.Strong.CP_ITEM
# Teamcenter.Soa.Client.Model.Strong.CP_Item_Folder
# Teamcenter.Soa.Client.Model.Strong.CP_PACKAGE
# Teamcenter.Soa.Client.Model.Strong.CP_REFERENCE
# Teamcenter.Soa.Client.Model.Strong.CreateInput
# Teamcenter.Soa.Client.Model.Strong.CrfExcelStylesheet
# Teamcenter.Soa.Client.Model.Strong.CrfHtmlStylesheet
# Teamcenter.Soa.Client.Model.Strong.CrfMSWordDocStylesheet
# Teamcenter.Soa.Client.Model.Strong.CrfOutputExcel
# Teamcenter.Soa.Client.Model.Strong.CrfOutputHtml
# Teamcenter.Soa.Client.Model.Strong.CrfOutputMSWord
# Teamcenter.Soa.Client.Model.Strong.CrfOutputPdf
# Teamcenter.Soa.Client.Model.Strong.CrfOutputText
# Teamcenter.Soa.Client.Model.Strong.CrfOutputXml
# Teamcenter.Soa.Client.Model.Strong.CrfPdfStylesheet
# Teamcenter.Soa.Client.Model.Strong.CrfQuerySource
# Teamcenter.Soa.Client.Model.Strong.CrfTextStylesheet
# Teamcenter.Soa.Client.Model.Strong.CrfXmlStylesheet
# Teamcenter.Soa.Client.Model.Strong.CR_approver
# Teamcenter.Soa.Client.Model.Strong.CR_approver_group
# Teamcenter.Soa.Client.Model.Strong.CR_approver_rig
# Teamcenter.Soa.Client.Model.Strong.CR_approver_role
# Teamcenter.Soa.Client.Model.Strong.CR_Job
# Teamcenter.Soa.Client.Model.Strong.CSYSInterfaceStorageClass
# Teamcenter.Soa.Client.Model.Strong.CsysProductInterface
# Teamcenter.Soa.Client.Model.Strong.CSYS_Interface_Form
# Teamcenter.Soa.Client.Model.Strong.CTDList
# Teamcenter.Soa.Client.Model.Strong.Dataset
# Teamcenter.Soa.Client.Model.Strong.DatasetType
# Teamcenter.Soa.Client.Model.Strong.DataType
# Teamcenter.Soa.Client.Model.Strong.DataTypeRef
# Teamcenter.Soa.Client.Model.Strong.DatumPoint
# Teamcenter.Soa.Client.Model.Strong.DatumPointMaster
# Teamcenter.Soa.Client.Model.Strong.DatumPointRevision
# Teamcenter.Soa.Client.Model.Strong.DatumPointRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.DatumPointRevision_Master
# Teamcenter.Soa.Client.Model.Strong.DatumPoint_Master
# Teamcenter.Soa.Client.Model.Strong.DCt_GraphicPriority
# Teamcenter.Soa.Client.Model.Strong.DCt_Language
# Teamcenter.Soa.Client.Model.Strong.DecisionTable
# Teamcenter.Soa.Client.Model.Strong.DeepCopyData
# Teamcenter.Soa.Client.Model.Strong.DeepCopyRule
# Teamcenter.Soa.Client.Model.Strong.DerivedObj
# Teamcenter.Soa.Client.Model.Strong.Derived_Thumbnail
# Teamcenter.Soa.Client.Model.Strong.Design
# Teamcenter.Soa.Client.Model.Strong.DesignMaster
# Teamcenter.Soa.Client.Model.Strong.DesignReq
# Teamcenter.Soa.Client.Model.Strong.DesignReqMaster
# Teamcenter.Soa.Client.Model.Strong.DesignReqMasterS
# Teamcenter.Soa.Client.Model.Strong.DesignReqRevision
# Teamcenter.Soa.Client.Model.Strong.DesignReqRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.DesignReqRevMasterS
# Teamcenter.Soa.Client.Model.Strong.DesignVerMaster
# Teamcenter.Soa.Client.Model.Strong.Design_Master
# Teamcenter.Soa.Client.Model.Strong.Design_Revision
# Teamcenter.Soa.Client.Model.Strong.Design_Revision_Master
# Teamcenter.Soa.Client.Model.Strong.DFA_KF
# Teamcenter.Soa.Client.Model.Strong.DgtSignatureByUserRelation
# Teamcenter.Soa.Client.Model.Strong.DirectModel
# Teamcenter.Soa.Client.Model.Strong.DirectModel3DMarkup
# Teamcenter.Soa.Client.Model.Strong.DirectModelAnimation
# Teamcenter.Soa.Client.Model.Strong.DirectModelAssembly
# Teamcenter.Soa.Client.Model.Strong.DirectModelFlowChart
# Teamcenter.Soa.Client.Model.Strong.DirectModelIllustrationBook
# Teamcenter.Soa.Client.Model.Strong.DirectModelIllustrationSheet
# Teamcenter.Soa.Client.Model.Strong.DirectModelMarkup
# Teamcenter.Soa.Client.Model.Strong.DirectModelMotion
# Teamcenter.Soa.Client.Model.Strong.DirectModelSession
# Teamcenter.Soa.Client.Model.Strong.Discipline
# Teamcenter.Soa.Client.Model.Strong.Disk
# Teamcenter.Soa.Client.Model.Strong.DispatcherRequest
# Teamcenter.Soa.Client.Model.Strong.DispatcherServiceArgument
# Teamcenter.Soa.Client.Model.Strong.DispatcherServiceConfig
# Teamcenter.Soa.Client.Model.Strong.DistributionList
# Teamcenter.Soa.Client.Model.Strong.DLFFormClass
# Teamcenter.Soa.Client.Model.Strong.DLF_Attribute_Form
# Teamcenter.Soa.Client.Model.Strong.DMI_markup
# Teamcenter.Soa.Client.Model.Strong.DMTemplate
# Teamcenter.Soa.Client.Model.Strong.DMTemplateForm
# Teamcenter.Soa.Client.Model.Strong.DMTemplateRevision
# Teamcenter.Soa.Client.Model.Strong.DMTemplateRevision_Master
# Teamcenter.Soa.Client.Model.Strong.DMTemplate_Master
# Teamcenter.Soa.Client.Model.Strong.Document
# Teamcenter.Soa.Client.Model.Strong.DocumentRevision
# Teamcenter.Soa.Client.Model.Strong.DocumentRevision_Master
# Teamcenter.Soa.Client.Model.Strong.Document_Master
# Teamcenter.Soa.Client.Model.Strong.Drawing
# Teamcenter.Soa.Client.Model.Strong.DrawingMaster
# Teamcenter.Soa.Client.Model.Strong.DrawingSheet
# Teamcenter.Soa.Client.Model.Strong.DrawingVerMaster
# Teamcenter.Soa.Client.Model.Strong.Drawing_Attributes
# Teamcenter.Soa.Client.Model.Strong.Drawing_AttributesStorage
# Teamcenter.Soa.Client.Model.Strong.Drawing_Master
# Teamcenter.Soa.Client.Model.Strong.Drawing_Revision
# Teamcenter.Soa.Client.Model.Strong.Drawing_Revision_Master
# Teamcenter.Soa.Client.Model.Strong.DXF
# Teamcenter.Soa.Client.Model.Strong.ECMAttributesTab
# Teamcenter.Soa.Client.Model.Strong.ECMChecklistTask
# Teamcenter.Soa.Client.Model.Strong.ECMChecklistTaskTemplate
# Teamcenter.Soa.Client.Model.Strong.ECMImpactAnalysisTask
# Teamcenter.Soa.Client.Model.Strong.ECMImpactAnalysisTaskTemplate
# Teamcenter.Soa.Client.Model.Strong.ECMPrepareECOTask
# Teamcenter.Soa.Client.Model.Strong.ECMPrepareECOTaskTemplate
# Teamcenter.Soa.Client.Model.Strong.ECMReferencersTab
# Teamcenter.Soa.Client.Model.Strong.ECM_base_revrule_relation
# Teamcenter.Soa.Client.Model.Strong.ECM_never_used
# Teamcenter.Soa.Client.Model.Strong.ECM_supercedure_to_form_reln
# Teamcenter.Soa.Client.Model.Strong.ECOSample
# Teamcenter.Soa.Client.Model.Strong.ECO_Sample_Form
# Teamcenter.Soa.Client.Model.Strong.ECRevMaster
# Teamcenter.Soa.Client.Model.Strong.ECSnapshot
# Teamcenter.Soa.Client.Model.Strong.EC_addressed_by_rel
# Teamcenter.Soa.Client.Model.Strong.EC_affected_item_rel
# Teamcenter.Soa.Client.Model.Strong.EC_affected_to_problem_relation
# Teamcenter.Soa.Client.Model.Strong.EC_problem_item_rel
# Teamcenter.Soa.Client.Model.Strong.EC_reference_item_rel
# ...
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.AttachmentInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.AuditFile
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.ChangeStateInputInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.ChangeStateOutput
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.ContextData
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.CreateSignoffInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.CreateSignoffs
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.DefinitionInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.GetResourcePoolOutput
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.GroupRoleRef
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.InstanceInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.ProcessTemplates
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.RemoveSignoffsInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.ResourcePoolInfo
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.Resources
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.Tasks
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.Templates
# Teamcenter.Services.Strong.Workflow._2008_06.Workflow.Workflow
# Teamcenter.Services.Strong.Workflow._2007_06.Workflow.ReleaseStatusInput
# Teamcenter.Services.Strong.Workflow._2007_06.Workflow.ReleaseStatusOption
# Teamcenter.Services.Strong.Workflow._2007_06.Workflow.SetReleaseStatusResponse
# Teamcenter.Services.Strong.Workflow._2007_06.Workflow.Workflow
# Teamcenter_SSO.sso_common.com.teamcenter._ss.util.SSOJsonUtil
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.server.ISSOServiceBinding
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.server.JsonHttpBinding
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.server.IWebRequestCreator
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.server.DefaultWebRequestCreator
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.client.login.SessionAgentJsonHttpBinding
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.client.login.IWebRequestCreator
# Teamcenter_SSO.sso_applib.com.teamcenter._ss.client.login.DefaultWebRequestCreator
# Teamcenter_SSO.sso_applib.com.teamcenter.ss.server.AbstractSSOAppSession
# Teamcenter_SSO.sso_applib.com.teamcenter.ss.server.AppSessionMethods
# Teamcenter_SSO.sso_applib.com.teamcenter.ss.server.AppSessionMethodsExtensions
# Teamcenter_SSO.sso_common.com.teamcenter._ss.util.SSOJsonUtil+<>c__DisplayClass0_0
# Teamcenter_SSO.sso_common.com.teamcenter._ss.util.SSOJsonUtil+<>c__DisplayClass0_1
# Teamcenter.Net.TcSSProxy.Client.CSSOConfigurationException
# Teamcenter.Net.TcSSProxy.Client.CSSOLoginFailureException
# Teamcenter.Net.TcSSProxy.Client.CSSOLoginCancelledException
# Teamcenter.Net.TcSSProxy.Client.CSSOAuthorizationException
# Teamcenter.Net.TcSSProxy.Client.CSSOSystemException
# Teamcenter.Net.TcSSProxy.Client.CSSOInvalidSessionException
# Teamcenter.Net.TcSSProxy.Client.CSSOInvalidTokenException
# Teamcenter.Net.TcSSProxy.Client.CSSODuplicateHandleException
# Teamcenter.Net.TcSSProxy.Client.CSSOException
# Teamcenter.Net.TcSSProxy.Client.ISSOSession
# Teamcenter.Net.TcSSProxy.Client.ISSOToken
# Teamcenter.Net.TcSSProxy.Client.ISSOAppToken
# Teamcenter.Net.TcSSProxy.Client.IHttpCookieToken
# Teamcenter.Net.TcSSProxy.Client.ISSOClient
# Teamcenter.Net.TcSSProxy.Client.ISSOLoginInput
# Teamcenter.Net.TcSSProxy.Client.ISSOLoginStatus
# Teamcenter.Net.TcSSProxy.Client.ISSOAppSession
# Teamcenter.Net.TcSSProxy.Client.NetBindingLoader
# Teamcenter.Soa.Client.Model.StrongObjectFactoryTie0aw
# Teamcenter.Soa.Client.Model.Strong.Tie0SchemaMap
# Teamcenter.Soa.Client.Model.StrongObjectFactoryTm0tsm
# Teamcenter.Soa.Client.Model.Strong.Tm0ReportXSL
# Teamcenter.Soa.Client.Model.Strong.Tm0TestActivity
# Teamcenter.Soa.Client.Model.Strong.Tm0TestActivityStorage
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCase
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseInstance
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseInstanceStorage
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseMaster
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseMasterS
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseRevision
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Tm0TestCaseRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Tm0TestDescriptionRel
# Teamcenter.Soa.Client.Model.Strong.Tm0TestInputRel
# Teamcenter.Soa.Client.Model.Strong.Tm0TestInstance
# Teamcenter.Soa.Client.Model.Strong.Tm0TestInstanceActivityRel
# Teamcenter.Soa.Client.Model.Strong.Tm0TestInstanceRel
# Teamcenter.Soa.Client.Model.Strong.Tm0TestInstanceStorage
# Teamcenter.Soa.Client.Model.Strong.Tm0TestResultRel
# Teamcenter.Soa.Client.Model.Strong.Tm0TestResults
# Teamcenter.Soa.Client.Model.Strong.Tm0TestScopeRel
# Teamcenter.Soa.Client.Model.StrongObjectFactoryTq0trainingqualification
# Teamcenter.Soa.Client.Model.Strong.Tq0AssignedQUDataProvider
# Teamcenter.Soa.Client.Model.Strong.Tq0AttendeeStatusTableRow
# Teamcenter.Soa.Client.Model.Strong.Tq0CourseAttendeeProvider
# Teamcenter.Soa.Client.Model.Strong.Tq0CourseDateTimeTableRow
# Teamcenter.Soa.Client.Model.Strong.Tq0CourseOffering
# Teamcenter.Soa.Client.Model.Strong.Tq0EffectivenssCheck
# Teamcenter.Soa.Client.Model.Strong.Tq0LatestReleasedQUProvider
# Teamcenter.Soa.Client.Model.Strong.Tq0ProfileQualDefinition
# Teamcenter.Soa.Client.Model.Strong.Tq0QProfileAttachments
# Teamcenter.Soa.Client.Model.Strong.Tq0QRecordAttachments
# Teamcenter.Soa.Client.Model.Strong.Tq0QualificationChecklist
# Teamcenter.Soa.Client.Model.Strong.Tq0QualificationDefinition
# Teamcenter.Soa.Client.Model.Strong.Tq0QualificationProfile
# Teamcenter.Soa.Client.Model.Strong.Tq0QualificationUnit
# Teamcenter.Soa.Client.Model.Strong.Tq0QualityDoc
# Teamcenter.Soa.Client.Model.Strong.Tq0QualityDocMaster
# Teamcenter.Soa.Client.Model.Strong.Tq0QualityDocMasterS
# Teamcenter.Soa.Client.Model.Strong.Tq0QualityDocRevision
# Teamcenter.Soa.Client.Model.Strong.Tq0QualityDocRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Tq0QualityDocRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Tq0QualProfileGroup
# Teamcenter.Soa.Client.Model.Strong.Tq0QualRecord
# Teamcenter.Soa.Client.Model.Strong.Tq0QUnitContent
# Teamcenter.Soa.Client.Model.Strong.Tq0TrainingQualProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactoryTxn0awtxnmonitor
# Teamcenter.Soa.Client.Model.Strong.Txn0AwTxnMonitorProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactoryUm0usermanagement
# Teamcenter.Soa.Client.Model.Strong.Um0AdminDataProvider
# Teamcenter.Soa.Client.Model.Strong.Um0AdminGroupdataProvider
# Teamcenter.Soa.Client.Model.Strong.Um0AdminRoledataProvider
# Teamcenter.Soa.Client.Model.Strong.Um0AdminUserdataProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactoryUml0umlsysml
# Teamcenter.Soa.Client.Model.Strong.Uml0AssignedUser
# Teamcenter.Soa.Client.Model.Strong.Uml0AssociatedModel
# Teamcenter.Soa.Client.Model.Strong.Uml0DependsOn
# Teamcenter.Soa.Client.Model.Strong.Uml0Element
# Teamcenter.Soa.Client.Model.Strong.Uml0ElementLink
# Teamcenter.Soa.Client.Model.Strong.Uml0MLModel
# Teamcenter.Soa.Client.Model.Strong.Uml0MLModelMaster
# Teamcenter.Soa.Client.Model.Strong.Uml0MLModelMasterS
# Teamcenter.Soa.Client.Model.Strong.Uml0MLModelRevision
# Teamcenter.Soa.Client.Model.Strong.Uml0MLModelRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Uml0MLModelRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Uml0Package
# Teamcenter.Soa.Client.Model.Strong.Uml0PackageMaster
# Teamcenter.Soa.Client.Model.Strong.Uml0PackageMasterS
# Teamcenter.Soa.Client.Model.Strong.Uml0PackageRevision
# Teamcenter.Soa.Client.Model.Strong.Uml0PackageRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Uml0PackageRevMasterS
# Teamcenter.Soa.Client.Model.StrongObjectFactoryUml1umlsysmlaw
# Teamcenter.Soa.Client.Model.Strong.Uml1ModelElement
# Teamcenter.Soa.Client.Model.StrongObjectFactoryUsp0supportal
# Teamcenter.Soa.Client.Model.Strong.Usp0ActivityTrackingInfo
# Teamcenter.Soa.Client.Model.Strong.Usp0AttachmentTrackingInfo
# Teamcenter.Soa.Client.Model.Strong.Usp0AttachTrackInfoProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0BriefcaseInfo
# Teamcenter.Soa.Client.Model.Strong.Usp0BriefcaseInfoProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0Briefcases
# Teamcenter.Soa.Client.Model.Strong.Usp0CompanyContactsProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0DesignXChange
# Teamcenter.Soa.Client.Model.Strong.Usp0DesignXChangeMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0DesignXChangeMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0DesignXChangeRevision
# Teamcenter.Soa.Client.Model.Strong.Usp0DesignXChangeRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0DesignXChangeRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0ListOfValuesString
# Teamcenter.Soa.Client.Model.Strong.Usp0OEMDeXChange
# Teamcenter.Soa.Client.Model.Strong.Usp0OEMDeXChangeMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0OEMDeXChangeMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0OEMDeXChangeRevision
# Teamcenter.Soa.Client.Model.Strong.Usp0OEMDeXChangeRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0OEMDeXChangeRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SponsorUsersProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0SRMXChange
# Teamcenter.Soa.Client.Model.Strong.Usp0SRMXChangeMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SRMXChangeMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SRMXChangeRevision
# Teamcenter.Soa.Client.Model.Strong.Usp0SRMXChangeRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SRMXChangeRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SupActivityInfoProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDataInfoProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDeXChange
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDeXChangeMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDeXChangeMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDeXChangeRevision
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDeXChangeRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SupDeXChangeRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SupInitExchg
# Teamcenter.Soa.Client.Model.Strong.Usp0SupInitExchgMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SupInitExchgMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SupInitExchgRevision
# Teamcenter.Soa.Client.Model.Strong.Usp0SupInitExchgRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SupInitExchgRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SuppliedBy
# Teamcenter.Soa.Client.Model.Strong.Usp0SupplierDataInfo
# Teamcenter.Soa.Client.Model.Strong.Usp0SupplierModObjProvider
# Teamcenter.Soa.Client.Model.Strong.Usp0SupXChange
# Teamcenter.Soa.Client.Model.Strong.Usp0SupXChangeMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SupXChangeMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0SupXChangeRevision
# Teamcenter.Soa.Client.Model.Strong.Usp0SupXChangeRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Usp0SupXChangeRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Usp0TransientAttributeInfo
# Teamcenter.Soa.Client.Model.StrongObjectFactoryUsp1supportalaw
# Teamcenter.Soa.Client.Model.Strong.Usp1ExchangeInfoProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactoryVal0nxvalidation
# Teamcenter.Soa.Client.Model.Strong.Val04GDAgent
# Teamcenter.Soa.Client.Model.Strong.Val04GDAgentMaster
# Teamcenter.Soa.Client.Model.Strong.Val04GDAgentMasterS
# Teamcenter.Soa.Client.Model.Strong.Val04GDAgentRevision
# Teamcenter.Soa.Client.Model.Strong.Val04GDAgentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val04GDAgentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val0AttachResultGroup
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDAgent
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDAgentMaster
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDAgentMasterS
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDAgentRevision
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDAgentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDAgentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValData
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValDataMaster
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValDataMasterS
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValDataRevision
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValDataRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValDataRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val0NX4GDValResult
# Teamcenter.Soa.Client.Model.Strong.Val0ResultGroup
# Teamcenter.Soa.Client.Model.Strong.Val0ValidationResult
# Teamcenter.Soa.Client.Model.Strong.Val0ValidationResultLog
# Teamcenter.Soa.Client.Model.Strong.Val0ValidationSummary
# Teamcenter.Soa.Client.Model.StrongObjectFactoryVal1cfgvalidation
# Teamcenter.Soa.Client.Model.Strong.Val1CfgAgent
# Teamcenter.Soa.Client.Model.Strong.Val1CfgAgentMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CfgAgentMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CfgAgentRevision
# Teamcenter.Soa.Client.Model.Strong.Val1CfgAgentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CfgAgentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CfgToolAgent
# Teamcenter.Soa.Client.Model.Strong.Val1CfgToolAgentMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CfgToolAgentMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CfgToolAgentRevision
# Teamcenter.Soa.Client.Model.Strong.Val1CfgToolAgentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CfgToolAgentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CfgValData
# Teamcenter.Soa.Client.Model.Strong.Val1CfgValDataMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CfgValDataMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CfgValDataRevision
# Teamcenter.Soa.Client.Model.Strong.Val1CfgValDataRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CfgValDataRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvaAgent
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvaAgentMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvaAgentMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvaAgentRevision
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvaAgentRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvaAgentRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvalData
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvalDataMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvalDataMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvalDataRevision
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvalDataRevisionMaster
# Teamcenter.Soa.Client.Model.Strong.Val1CondEvalDataRevMasterS
# Teamcenter.Soa.Client.Model.Strong.Val1CondValResult
# Teamcenter.Soa.Client.Model.Strong.Val1ValResult
# Teamcenter.Soa.Client.Model.StrongObjectFactoryVm1vendormanagementaw
# Teamcenter.Soa.Client.Model.Strong.Vm1AssignedObjsDataProvider
# Teamcenter.Soa.Client.Model.Strong.Vm1VendorLocationProvider
# Teamcenter.Soa.Client.Model.Strong.Vm1VendorPartsProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactoryWnb0weightandbalance
# Teamcenter.Soa.Client.Model.Strong.Wnb0CGEnvelope
# Teamcenter.Soa.Client.Model.Strong.Wnb0CGEnvelopeRow
# Teamcenter.Soa.Client.Model.Strong.Wnb0CGMeasurableAttribute
# Teamcenter.Soa.Client.Model.Strong.Wnb0CGMeasureValue
# Teamcenter.Soa.Client.Model.Strong.Wnb0MassAndBalanceAttr
# Teamcenter.Soa.Client.Model.Strong.Wnb0MassMeasurableAttribute
# Teamcenter.Soa.Client.Model.Strong.Wnb0MassMeasurement
# Teamcenter.Soa.Client.Model.Strong.Wnb0MassMeasureValue
# Teamcenter.Soa.Client.Model.Strong.Wnb0MoIMeasurableAttribute
# Teamcenter.Soa.Client.Model.Strong.Wnb0MoIMeasureValue
# Teamcenter.Soa.Client.Model.Strong.Wnb0Payload
# Teamcenter.Soa.Client.Model.Strong.Wnb0PayloadCollection
# Teamcenter.Soa.Client.Model.Strong.Wnb0PayloadCollectProvider
# Teamcenter.Soa.Client.Model.Strong.Wnb0PayloadRelation
# Teamcenter.Soa.Client.Model.Strong.Wnb0PayloadRow
# Teamcenter.Soa.Client.Model.Strong.Wnb0PoIMeasurableAttribute
# Teamcenter.Soa.Client.Model.Strong.Wnb0PoIMeasureValue
# Teamcenter.Soa.Client.Model.Strong.Wnb0RollupReport
# Teamcenter.Soa.Client.Model.Strong.Wnb0RollupReportsProvider
# Teamcenter.Soa.Client.Model.Strong.Wnb0RollupTemplateProvider
# Teamcenter.Soa.Client.Model.StrongObjectFactoryXc0sharecollaboration
# Teamcenter.Soa.Client.Model.Strong.Xc0XCCTxnInput
# Teamcenter.Soa.Client.Model.StrongObjectFactoryXst0xsearch
# Teamcenter.Soa.Client.Model.Strong.Xst0DataAccessProfile
# Teamcenter.Soa.Client.Model.Strong.Xst0ExternalSystemObject
# Teamcenter.Soa.Client.Model.Strong.Xst0ReferencesProvider

# %%
# 1) Load DLLs first (your glob loader is fine).
# 2) Then:
# from dm_resolver import resolve_dm_namespace, get_service_factory, list_available_dm_namespaces

# Optional: see what Datamanagement namespaces actually exist:
for n in list_available_dm_namespaces():
    print(" •", n)

# Resolve (with debug prints):
DMService, DMTypes, DM_FLAVOR, DM_TYPES_NS = resolve_dm_namespace(verbose=True)
getService = get_service_factory(DMService)

print("\nSummary:")
print("  flavor     :", DM_FLAVOR)
print("  service    :", DMService)
print("  types ns   :", DM_TYPES_NS)
# Out:
#  • Abr0.Services.Strong.Advancedbomrollup._2023_12.DataManagement
#  • Abr0.Services.Strong.Advancedbomrollup._2024_06.DataManagement
#  • Awb0.Services.Internal.Strong.Activeworkspacebom._2019_12.DataManagement
#  • Awn0.Services.Internal.Strong.Nx._2020_05.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2012_10.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2013_12.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2015_10.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2016_03.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2016_04.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2016_12.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2017_06.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2017_12.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2018_05.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2019_06.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2020_05.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2020_12.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2021_12.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2022_12.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2023_06.DataManagement
#  • Awp0.Services.Internal.Strong.Aws2._2024_06.DataManagement
#  • Awv0.Services.Strong.Activeworkspacevis._2015_03.DataManagement
#  • Cif0.Services.Internal.Strong.Integrationframework._2024_06.DataManagement
#  • Cif0.Services.Strong.Integrationframework._2017_11.DataManagement
#  • Cpd0.Services.Internal.Strong.Cpdcore._2017_05.DataManagement
#  • Cpd0.Services.Internal.Strong.Cpdcore._2017_11.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2011_06.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2012_06.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2014_10.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2015_07.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2016_10.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2017_05.DataManagement
#  • Cpd0.Services.Strong.Cpdcore._2020_01.DataManagement
#  • Ewi0.Services.Strong.Ewia._2012_10.DataManagement
#  • Ewi0.Services.Strong.Ewia._2015_03.DataManagement
#  • Fdp0.Services.Internal.Strong.Fourdplanning._2013_05.DataManagement
#  • Fdp0.Services.Internal.Strong.Fourdplanning._2013_12.DataManagement
#  • Fdp0.Services.Strong.Fourdplanning._2013_05.DataManagement
#  • Fnd0.Services.Strong.Editcontext._2014_12.DataManagement
#  • Fnd0.Services.Strong.Editcontext._2015_07.DataManagement
#  • Fnd0.Services.Strong.Editcontext._2016_04.DataManagement
#  • Fnd0.Services.Strong.Editcontext._2016_10.DataManagement
#  • Mac0.Services.Internal.Strong.Manufacturingcore._2017_05.DataManagement
#  • Mac0.Services.Internal.Strong.Manufacturingcore._2018_06.DataManagement
#  • Mac0.Services.Strong.Manufacturingcore._2017_05.DataManagement
#  • Mbc0.Services.Internal.Strong.Mfgbvrcore._2014_06.DataManagement
#  • Mbc0.Services.Internal.Strong.Mfgbvrcore._2015_03.DataManagement
#  • Mbc0.Services.Internal.Strong.Mfgbvrcore._2016_04.DataManagement
#  • Mbc0.Services.Internal.Strong.Mfgbvrcore._2022_12.DataManagement
#  • Mbc0.Services.Internal.Strong.Mfgbvrcore._2023_12.DataManagement
#  • Mbc0.Services.Strong.Mfgbvrcore._2014_06.DataManagement
#  • Mdl0.Services.Strong.Modelcore._2011_06.DataManagement
#  • Mdl0.Services.Strong.Modelcore._2014_06.DataManagement
#  • Mdl0.Services.Strong.Modelcore._2014_10.DataManagement
#  • Teamcenter.Services.Internal.Strong.Cad._2007_12.DataManagement
#  • Teamcenter.Services.Internal.Strong.Cad._2008_03.DataManagement
#  • Teamcenter.Services.Internal.Strong.Cad._2008_05.DataManagement
#  • Teamcenter.Services.Internal.Strong.Cad._2008_06.DataManagement
#  • Teamcenter.Services.Internal.Strong.Cad._2010_04.DataManagement
#  • Teamcenter.Services.Internal.Strong.Cad._2013_05.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2007_01.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2007_09.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2008_06.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2010_04.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2010_09.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2012_02.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2012_10.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2016_10.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2017_11.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2021_06.DataManagement
#  • Teamcenter.Services.Internal.Strong.Core._2021_12.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2011_12.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2014_06.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2016_09.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2017_05.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2020_01.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2020_04.DataManagement
#  • Teamcenter.Services.Internal.Strong.Manufacturing._2020_12.DataManagement
#  • Teamcenter.Services.Internal.Strong.Visualization._2008_06.DataManagement
#  • Teamcenter.Services.Internal.Strong.Visualization._2010_04.DataManagement
#  • Teamcenter.Services.Internal.Strong.Visualization._2010_09.DataManagement
#  • Teamcenter.Services.Internal.Strong.Visualization._2012_10.DataManagement
#  • Teamcenter.Services.Internal.Strong.Visualization._2017_05.DataManagement
#  • Teamcenter.Services.Internal.Strong.Visualization._2022_06.DataManagement
#  • Teamcenter.Services.Strong.Cad._2007_01.DataManagement
#  • Teamcenter.Services.Strong.Cad._2007_12.DataManagement
#  • Teamcenter.Services.Strong.Cad._2008_03.DataManagement
#  • Teamcenter.Services.Strong.Cad._2008_06.DataManagement
#  • Teamcenter.Services.Strong.Cad._2010_09.DataManagement
#  • Teamcenter.Services.Strong.Cad._2011_06.DataManagement
#  • Teamcenter.Services.Strong.Cad._2012_09.DataManagement
#  • Teamcenter.Services.Strong.Cad._2014_10.DataManagement
#  • Teamcenter.Services.Strong.Cad._2016_03.DataManagement
#  • Teamcenter.Services.Strong.Core._2006_03.DataManagement
#  • Teamcenter.Services.Strong.Core._2007_01.DataManagement
#  • Teamcenter.Services.Strong.Core._2007_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2007_09.DataManagement
#  • Teamcenter.Services.Strong.Core._2007_12.DataManagement
#  • Teamcenter.Services.Strong.Core._2008_05.DataManagement
#  • Teamcenter.Services.Strong.Core._2008_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2009_10.DataManagement
#  • Teamcenter.Services.Strong.Core._2010_04.DataManagement
#  • Teamcenter.Services.Strong.Core._2010_09.DataManagement
#  • Teamcenter.Services.Strong.Core._2011_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2012_02.DataManagement
#  • Teamcenter.Services.Strong.Core._2012_09.DataManagement
#  • Teamcenter.Services.Strong.Core._2012_10.DataManagement
#  • Teamcenter.Services.Strong.Core._2013_05.DataManagement
#  • Teamcenter.Services.Strong.Core._2014_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2014_10.DataManagement
#  • Teamcenter.Services.Strong.Core._2015_07.DataManagement
#  • Teamcenter.Services.Strong.Core._2015_10.DataManagement
#  • Teamcenter.Services.Strong.Core._2016_05.DataManagement
#  • Teamcenter.Services.Strong.Core._2016_09.DataManagement
#  • Teamcenter.Services.Strong.Core._2018_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2019_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2020_01.DataManagement
#  • Teamcenter.Services.Strong.Core._2020_04.DataManagement
#  • Teamcenter.Services.Strong.Core._2021_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2023_06.DataManagement
#  • Teamcenter.Services.Strong.Core._2023_12.DataManagement
#  • Teamcenter.Services.Strong.Core._2024_06.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2008_06.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2009_10.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2011_06.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2012_02.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2012_09.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2013_05.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2014_06.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2017_11.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2018_06.DataManagement
#  • Teamcenter.Services.Strong.Manufacturing._2019_06.DataManagement
#  • Teamcenter.Services.Strong.Visualization._2011_02.DataManagement
#  • Teamcenter.Services.Strong.Visualization._2013_05.DataManagement
#  • Teamcenter.Services.Strong.Visualization._2016_03.DataManagement
#  • Txl0.Services.Internal.Strong.Tcxlite._2022_12.DataManagement
# [dm] service: Teamcenter.Services.Strong.Cad.DataManagementService  (base_ns=Teamcenter.Services.Strong.Cad, flavor=strong)
# [dm] types: Teamcenter.Services.Strong.Cad._2008_03.DataManagement
#
# Summary:
#   flavor     : strong
#   service    : Teamcenter.Services.Strong.Cad.DataManagementService
#   types ns   : Teamcenter.Services.Strong.Cad._2008_03.DataManagement

# %%
dir(DMTypes)
# Out:
# ['CadAttrMappingDefinitionInfo',
#  'DataManagement',
#  'DatasetInfo3',
#  'MappedDatasetAttrPropertyInfo',
#  'PartInfo3',
#  'ResolveAttrMappingsInfo',
#  'ResolveAttrMappingsResponse',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__file__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__loader__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__package__',
#  '__path__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__spec__',
#  '__str__',
#  '__subclasshook__']

# %%
# list a few names in the resolved DM types namespace
names = [n for n in dir(DMTypes) if "GetItem" in n or "Related" in n]
print(names[:50])
# Out:
# []

# %%
# dm_resolver.py
from __future__ import annotations
from typing import Any, Optional, Tuple
import sys

import clr  # already loaded
from System import Array
from System import String
from System import Type
from System import Version
from System import AppDomain

# Utility: call getService/GetService without caring about casing
def _get_service_factory(dm_service_type) -> Any:
    for name in ("getService", "GetService"):
        if hasattr(dm_service_type, name):
            return getattr(dm_service_type, name)
    raise AttributeError(
        f"{dm_service_type.FullName} exposes neither getService nor GetService."
    )

def _import_ns(ns: str) -> Optional[Any]:
    try:
        # __import__ with fromlist ensures we actually load the tail module
        return __import__(ns, fromlist=['*'])
    except Exception:
        return None

def resolve_dm_namespace() -> Tuple[Any, Any, str]:
    """
    Locate Teamcenter's DataManagement service + its request/response types.

    Returns:
        (DMServiceClass, DMTypesNamespaceOrStr, 'strong'|'weak')

    DMTypesNamespaceOrStr is either a Python module (preferred) or a namespace string
    (when we couldn't import the module but we still know the namespace).
    """
    # 1) Find the service type by reflection across all loaded assemblies
    asms = list(AppDomain.CurrentDomain.GetAssemblies())
    candidates = []
    for asm in asms:
        try:
            for t in asm.GetTypes():
                # We only care about DataManagementService under Teamcenter.Services.*
                if (t is not None and t.Name == "DataManagementService"
                        and t.Namespace is not None
                        and t.Namespace.startswith("Teamcenter.Services")):
                    candidates.append(t)
        except Exception:
            # Dynamic/ref emit assemblies can throw on GetTypes(); ignore
            continue

    if not candidates:
        raise ImportError(
            "Could not locate DataManagementService in any loaded assembly. "
            "Double-check that TcSoaCoreStrong.dll and/or TcSoaCommon.dll + TcSoaClient.dll are loaded, "
            "and that no 32-bit DLLs are being mixed into a 64-bit process."
        )

    # Prefer Strong over Core (weak-typed)
    strong = [t for t in candidates if ".Strong." in t.Namespace]
    dm_service_type = (strong or candidates)[0]
    flavor = "strong" if ".Strong." in dm_service_type.Namespace else "weak"

    # 2) Figure out the companion types namespace
    # Example: Teamcenter.Services.Strong.Core._2008_06.DataManagementService  ->
    #          types under Teamcenter.Services.Strong.Core._2008_06.Datamanagement (or DataManagement)
    base_ns = dm_service_type.Namespace
    dm_types_mod = None
    dm_types_ns = None

    for suffix in ("Datamanagement", "DataManagement"):
        probe = f"{base_ns}.{suffix}"
        dm_types_mod = _import_ns(probe)
        if dm_types_mod is not None:
            dm_types_ns = probe
            break

    # If still not found, try a rep type (works even when types are in a sibling assembly)
    if dm_types_mod is None:
        rep_names = (
            "GetItemFromIdInput",
            "GetItemAndRelatedObjectsInput",
            "GetItemResponse",
            "GetItemAndRelatedObjectsResponse",
        )
        best_hit = None
        for asm in asms:
            try:
                for t in asm.GetTypes():
                    if t is None or t.Namespace is None:
                        continue
                    if not t.Namespace.startswith(base_ns):
                        continue
                    if t.Name in rep_names:
                        best_hit = t
                        break
                if best_hit:
                    break
            except Exception:
                continue
        if best_hit:
            dm_types_ns = best_hit.Namespace
            dm_types_mod = _import_ns(dm_types_ns)

    if dm_types_ns is None:
        raise ImportError(
            f"Found service type {dm_service_type.FullName}, but could not resolve its types "
            f"(e.g., {base_ns}.Datamanagement / {base_ns}.DataManagement). "
            "Check your client kit; some highly customized kits rename/relocate the types."
        )

    # 3) Return the class (not an instance), plus the module/namespace
    return dm_service_type, (dm_types_mod or dm_types_ns), flavor


# Quick self-test (optional): prints the resolved bits when run standalone
# DMService, DMTypes, FLAVOR = resolve_dm_namespace()
# print(f"[dm] flavor={FLAVOR} service={DMService.FullName} types={(getattr(DMTypes, '__name__', DMTypes))}")

# %%
# After your dll-loading block:
# from dm_resolver import resolve_dm_namespace, _get_service_factory

DMService, DMTypes, DM_FLAVOR = resolve_dm_namespace()
getService = _get_service_factory(DMService)

# later, once you have a Connection conn:
dm = getService(conn)   # works whether the method is getService or GetService

# DMTypes is either a module with classes OR a namespace string.
# If it’s a string, construct types by full name via reflection:
from System import Activator
from System import Type as NetType

def _new(fullname: str):
    t = NetType.GetType(fullname, throwOnError=True)
    return Activator.CreateInstance(t)

# Example: create GetItemFromIdInput no matter where it lives
try:
    # Prefer direct class access when we have a real module
    GetItemFromIdInput = getattr(DMTypes, "GetItemFromIdInput")
    inp = GetItemFromIdInput()
except Exception:
    # Fallback to reflection with the resolved namespace string
    ns = DMTypes if isinstance(DMTypes, str) else DMTypes.__name__
    inp = _new(f"{ns}.GetItemFromIdInput")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 4
#       1 # After your dll-loading block:
#       2 # from dm_resolver import resolve_dm_namespace, _get_service_factory
# ----> 4 DMService, DMTypes, DM_FLAVOR = resolve_dm_namespace()
#       5 getService = _get_service_factory(DMService)
#       7 # later, once you have a Connection conn:
#
# Cell In[33], line 108, in resolve_dm_namespace()
#     105         dm_types_mod = _import_ns(dm_types_ns)
#     107 if dm_types_ns is None:
# --> 108     raise ImportError(
#     109         f"Found service type {dm_service_type.FullName}, but could not resolve its types "
#     110         f"(e.g., {base_ns}.Datamanagement / {base_ns}.DataManagement). "
#     111         "Check your client kit; some highly customized kits rename/relocate the types."
#     112     )
#     114 # 3) Return the class (not an instance), plus the module/namespace
#     115 return dm_service_type, (dm_types_mod or dm_types_ns), flavor
#
# ImportError: Found service type Teamcenter.Services.Strong.Cad.DataManagementService, but could not resolve its types (e.g., Teamcenter.Services.Strong.Cad.Datamanagement / Teamcenter.Services.Strong.Cad.DataManagement). Check your client kit; some highly customized kits rename/relocate the types.

# %%
import clr  # pythonnet

# These are the usual assemblies needed for SOA + services + file mgmt
for asm in (
    "TcSoaCommon",
    "TcSoaClient",
    "TcServicesStrongCore",
    "TcServicesCore",  # weak-typed fallback
):
    try:
        clr.AddReference(asm)
    except Exception:
        # Some sites don't ship all of these; we'll probe dynamically below.
        pass

# Base client types (use .NET casing)
from Teamcenter.Soa.Client import Connection, FileManagementUtility, DefaultExceptionHandler  # type: ignore
# ResponseExceptionHandler is not in all client kits; don't import it unless you truly need it.

# %%
# -----------------------------------------------------------------------------
# Robust resolver for DataManagement service + its Datamanagement types
# -----------------------------------------------------------------------------
from typing import Any, Tuple

def resolve_dm_namespace() -> Tuple[Any, Any, str]:
    """
    Try to resolve a DataManagement service in this priority:
      1) Strong.Core (unversioned)
      2) Strong.Core._2008_06
      3) Strong.Core._2007_06
      4) Strong.Core._2006_03
      5) Core (weak-typed, unversioned service + _2006_03 Datamanagement types)

    Returns:
        (DMServiceClass, DMTypesNamespace, 'strong'|'weak')
    Raises:
        ImportError if none can be found.
    """
    # 1) Strong, unversioned (service sits directly under Strong.Core in some kits)
    try:
        import Teamcenter.Services.Strong.Core as StrongCore
        DMService = StrongCore.DataManagementService  # type: ignore[attr-defined]
        # Companion Datamanagement types are typically versioned even if service is not
        try:
            from Teamcenter.Services.Strong.Core._2008_06 import Datamanagement as DMTypes  # type: ignore
        except Exception:
            # Fall back to older type packages if needed
            for ver in ("_2007_06", "_2006_03"):
                try:
                    DMTypes = __import__(f"Teamcenter.Services.Strong.Core.{ver}", fromlist=["Datamanagement"]).Datamanagement  # type: ignore
                    break
                except Exception:
                    DMTypes = None
            if DMTypes is None:
                raise ImportError("Strong.Core Datamanagement types not found")
        return DMService, DMTypes, "strong"
    except Exception:
        pass

    # 2…4) Strong, versioned service (most common is _2008_06)
    for ver in ("_2008_06", "_2007_06", "_2006_03"):
        try:
            ver_ns = __import__(f"Teamcenter.Services.Strong.Core.{ver}", fromlist=["DataManagementService", "Datamanagement"])
            DMService = getattr(ver_ns, "DataManagementService")
            DMTypes = getattr(ver_ns, "Datamanagement")
            return DMService, DMTypes, "strong"
        except Exception:
            continue

    # 5) Weak-typed Core fallback (almost always available)
    try:
        import Teamcenter.Services.Core as Core
        from Teamcenter.Services.Core._2006_03 import DataManagement as DMTypes  # inputs/outputs live here
        DMService = Core.DataManagementService  # unversioned weak-typed service
        return DMService, DMTypes, "weak"
    except Exception:
        pass

    raise ImportError(
        "Could not resolve any DataManagement service. "
        "Ensure your TC client kit includes either Teamcenter.Services.Strong.Core or Teamcenter.Services.Core, "
        "and that TC_BIN points to the folder with those DLLs."
    )

# Example: bind once at import time
DMService, DMTypes, DM_FLAVOR = resolve_dm_namespace()
print(f"[dm] using {DM_FLAVOR} typed DataManagement: {DMService} with types {DMTypes}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 67
#      60     raise ImportError(
#      61         "Could not resolve any DataManagement service. "
#      62         "Ensure your TC client kit includes either Teamcenter.Services.Strong.Core or Teamcenter.Services.Core, "
#      63         "and that TC_BIN points to the folder with those DLLs."
#      64     )
#      66 # Example: bind once at import time
# ---> 67 DMService, DMTypes, DM_FLAVOR = resolve_dm_namespace()
#      68 print(f"[dm] using {DM_FLAVOR} typed DataManagement: {DMService} with types {DMTypes}")
#
# Cell In[30], line 60, in resolve_dm_namespace()
#      57 except Exception:
#      58     pass
# ---> 60 raise ImportError(
#      61     "Could not resolve any DataManagement service. "
#      62     "Ensure your TC client kit includes either Teamcenter.Services.Strong.Core or Teamcenter.Services.Core, "
#      63     "and that TC_BIN points to the folder with those DLLs."
#      64 )
#
# ImportError: Could not resolve any DataManagement service. Ensure your TC client kit includes either Teamcenter.Services.Strong.Core or Teamcenter.Services.Core, and that TC_BIN points to the folder with those DLLs.
